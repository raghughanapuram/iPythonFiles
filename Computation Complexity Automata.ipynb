# %% [markdown]
# **Automata, Computability, and Complexity** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-045j-automata-computability-and-complexity-spring-2011/index.htm)
#
# 1. Introduction
# 2. Logic, circuits, and gates
# 3. Deterministic finite automata(DFAs) and nondeterministic finite automata (NFAs)
# 4. NFAs and regular expressions
# 5. Non-regular languages and the pumping lemma
# 6. Turing machines
# 7. Decidability
# 8. Undecidable problems and Post correspondence problem (PCP)
# 9. Mapping reducibility and Rice's theorem
# 10. Self-reference and the recursion theorem
# 11. Introduction to cryptography
# 12. Complexity theory
# 13. Pseudorandom generators and one-way functions
# 14. Public-key cryptography
# 15. More complexity theory
# 16. More NP-completeness
# 17. Probabilistic Turing machines and complexity classes
# 18. Trapdoor one-way functions and zero-knowledge proofs
# 19. Probably approximately correct (PAC) learning
# 20. More PAC learning
# 21. Introduction to quantum
# 22. Quantum Mechanics and BQP
# 23. Quantum algorithms
#
# - Texts:
#     - More, Mertens (2011) *The Nature of Computation*
#     - Sipser (2005) *Introduction to the theory of computation*
#     - Sanjeev & Barak (2009) *Computational Complexity: A Modern Approach*

# %% [markdown]
# **Theory of Computation** [MIT OpenCourseware](http://ocw.mit.edu/courses/mathematics/18-404j-theory-of-computation-fall-2006)
#
# 1. Introduction, Finite Automata, Regular expressions
# 2. Nondeterminism, Closure Properties, Regular Expressions <-> FA
# 3. Regular Pumping Lemma, Context Free Languages
# 4. Pushdown Automata, CFG <-> PDA
# 5. CF Pumping Lemma, Turing Machines
# 6. TM Variants, Church-Turing thesis
# 7. Decision Problems for Automata and Grammars
# 8. Undecidability
# 9. Reducibility
# 10. Linearly Bounded Automata, PCP
# 11. Recursion Theorem and Logic
# 12. Time Complexity
# 13. P and NP, SAT, Poly-time Reducibility
# 14. NP-Completeness
# 15. Cook-Levin Theorem
# 16. Space Complexity
# 17. PSPACE, TQBF, Savaitch's Theorem
# 18. Games, Generalized Geography
# 19. L and NL, NL = coNL
# 20. Hierarchy Theorems
# 21. Provably untractable Problems, Oracles
# 22. Probabilistic Computation, BPP
# 23. Probabilistic Computation (cont)
# 24. Interactive Proof Sytems, IP

# %% [markdown]
# **Evolution of Complexity** Richard Watson [Home Page](http://www.ecs.soton.ac.uk/people/raw) [Manifesto on Algortihmic Evolution](http://www.ecs.soton.ac.uk/~raw/) [Course Page](http://www.ecs.soton.ac.uk/module/COMP6202)
#
# 1. Introduction to algorithmic concepts of evolution
#     - What is evolution?
#     - Natural selection and adaptation
#     - Evolutionary algorithms
#     - Algorithm variants (genetic algorithms, evolutionary strategies, etc.)
# 2. Computational optimization methods
#     - Combinatorial optimization (e.g. TSP, graph-colouring)
#     - Heuristic techniques (e.g., Simulated annearling, gradient ascent)
# 3. Evolvability of Complex Systems
#     - Concepts of evolutionary difficulty (fitness landscapes, epistasis, adaptation and constraint)
#     - Modularity
#     - sexual recombination and evolvability
#     - algorithmic possibilities for evolution
#     - artificial life models, open-ended evolution
#     - developmental representations
# 4. Advanced Topics
#     - Wright versus Fisher (mass selection, shifting balance theory)
#     - units of selection
#     - interactions among species (coevolution, coadaptation
#     - compositional evolution (hybridisation, major evolutionary transitions)
#     - macro-evolution (saltations, gradualism, extinction, trends, diversity, species and speciation)
#
# - Texts:
#     - Evolutionary computation: A Unified Approach, De Jong 2006
#     - How to Solve It: Modern Heuristics, Michalewicz and Fogel 2004
#     - The Origins of Order, Stuart Kauffman
#     - The Selfish Gene, Richard Dawkins

# %% [markdown]
# - **Theory of Computing**
#     - Automata theory
#         - Finite state automata, regular expressions and regular languages
#         - The pumping lemma for regular languages
#         - Closure properties of regular languages
#         - The Myhill-Nerode theorem
#         - Context-free grammars and pushdown automata
#         - Closure properties of context-free languages
#         - The pumping lemma for context-free languages
#     - Computability theory
#         - Turing machines, recursively enumerable and recursive languages
#         - Church-Turing thesis
#         - Limitations of algorithms: universality, the halting problem and undecidability
#     - Computational complexity theory
#         - Complexity of algorithms and of problems
#         - Complexity classes P, NP, PSPACE
#         - Polynomial-time reduction
#         - NP-Completeness and Cook's theorem
#         - PSPACE-Completeness
#
# - Texts:
#     - Dexter C. Kozen, Automata and Computabilty, Springer, 1999
#     - Sipser M, Introduction to the Theory of Computation, PWS, 1997.
#     - Hein J, Discrete Structures, Logic, and Computability 2nd Edition, Jones and Bartlett, 2002.
#     - Dewdney AK, The (new) Turing Omnibus, Henry Holt, 2001.
#     - Harel D, Algorithmics: The Spirit of Computing 2nd Edition, Addison Wesley, 1992.
#     - Barwise J and Etchemendy J, Turing's World, Stanford, 1993.
#     - Cohen D, Introduction to Computer Theory 2nd Edition, Wiley, 1996.
#     - Feynman Lectures on Computation, Addison Wesley, 1996.
#     - Jones ND, Computability and Complexity, MIT, 1997.
#     - Gruska J, Foundations of Computing, Thomson, 1996

# %% [markdown]
# - **Automata, Computability, and Complexity** [page](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-045j-automata-computability-and-complexity-spring-2011/index.htm)
#     1. Introduction
#     2. Logic, circuits and gates
#     3. Deterministic finite automata (DFAs) and nondeterministic finite automata (NFAs)
#     4. NFAs and regular expressions
#     5. Non-regular languages and the pumping lemma
#     6. Turing machines
#     7. Decidability
#     8. Undecidability
#     9. Undecidable problems and Post correspondence problem (PCP)
#     10. Mapping reducibility and Rice's theorem
#     11. Self-reference and the recursion theorem
#     12. Introduction to cryptography
#     13. Complexity theory
#     14. Pseudorandom number generators and one-way functions
#     15. Public-key cryptography
#     16. More complexity theory
#     17. More NP-completeness
#     18. Probabilistic Turing machines and complexity classes
#     19. Trapdoor one-way functions and zero-knowledge proofs
#     20. Probably approximately correct (PAC) learning
#     21. More PAC learning
#     22. Introduction to quantum
#     23. Quantum mechanics and BQP
#     24. Quantum algorithms

# %% [markdown]
# - **Theory of Computation** [page](http://ocw.mit.edu/courses/mathematics/18-404j-theory-of-computation-fall-2006/index.htm)
#     1. Introduction, Finite Automata, Regular Expressions
#     2. Nondeterminism, Closure Properties, Regular Expression <-> FA
#     3. Regular Pumping Lemma, Context Free Languages
#     4. Pushdown Automata, CFG <-> PDA
#     5. CF Pumping Lemma, Turing Machines
#     6. TM Variants, Church-Turing Thesis
#     7. Decision Problems for Automata and Grammars
#     8. Undecidability
#     9. Reducibility
#     10. Linearly Bounded Automata, PCP
#     11. Recursion Theorem and Logic
#     12. Time Complexity
#     13. P and NP, SAT, Poly-time Reducibility
#     14. NP-Completeness
#     15. Cook-Levin Theorem
#     16. Space Complexity
#     17. PSPACE, TQBF, Savitch's Theorem
#     18. Games, Generalized Geography
#     19. L and NL, NL = coNL
#     20. Hierarchy Theorems
#     21. Provably Intractable Problems, Oracles
#     22. Probabilistic Computation, BPP
#     23. Interactive Proof Systems, IP
