# %% [markdown]
# **Computation Structures** (Chris Terman) [Playlist](https://www.youtube.com/channel/UCsYAKnygt826Hsk7_Op56eg) [Course Page](http://6004.mit.edu/Fall13/)
#
# 1. Basics of information
# 2. The Digital Abstraction
# 3. CMOS Technology
# 4. Logic Synthesis
# 5. Sequential Logic
# 6. Finite State Machines
# 7. Synchronization
# 8. Pipelining
# 9. Cost/Performance Tradeoffs
# 10. Programmable Machines
# 11. Designin an Instruction Set
# 12. Machine Language and Compilers
# 13. Stacks and Procedures
# 14. Building the Beta
# 15. The Memory Hierarchy
# 16. Cache Issues
# 17. Virtual Memory
# 18. Virtual Machines
# 19. Device Handlers & Real Time
# 20. Interconnect and Communication
# 21. Processes, Synchronization & Deadlock
# 22. Pipelining the Beta
# 23. Pipeline Issues
# 24. Parallel Processing
# 25. Engineering Practice

# %% [markdown]
# ** Computer System Architecture** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-823-computer-system-architecture-fall-2005/)
#
# 1. History of Calculation and Computer Architecture
# 2. Influence of Technology and Software on Instruction Sets: Up to the dawn of IBM 360
# 3. Complex Instruction Set Evolution in the Sixties: Stack and GPR Architectures
# 4. Microprogramming
# 5. Simple Instruction Pipeline
# 6. Pipeline Hazards
# 7. Multi-level Memories - Technology
# 8. Cache (Memory) Performance Optimization
# 9. Virtual Memory Basics
# 10. Virtual Memory 2
# 11. Complex Pipelining
# 12. Out of Order Execution and Register Renaming
# 13. Branch prediction and Speculative Execution
# 14. Advanced Superscalar Architectures
# 15. Microprocessor Evolution: 4004 to Pentium 4
# 16. Synchronization and Sequential Consistency
# 17. Cache coherence
# 18. Cache coherence (Implementation)
# 19. Snoopy Protocols
# 20. Relaxed Memory Models
# 21. VLIW/EPIC: Statically Scheduled ILP
# 22. Vector Computers
# 23. Multithreaded Processors
# 24. Reliable Architectures
# 25. Virtual machines
#
# - Texts:
#     - Hennessey, & Patterson (2002) *Computer Architecture: A Quantitative Approach*
#     - Patternson & Hennessey (2004) *Computer Organization and Design: The Hardward/Software Interface*
#
# **Principles of Computer Systems** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-826-principles-of-computer-systems-spring-2002/index.htm)
#
# 1. Course Information, Spec language
# 2. Disks and File Systems
# 3. Generalizing Abstraction Functions
# 4. Atomic Semantics of Spec
# 5. Performance, Firefly RPC
# 6. Naming, Semantic File System
# 7. Concurrency
# 8. Formal Concurrency
# 9. Consensus
# 10. Sequential Transactions with Caching
# 11. Concurrent Transactions
# 12. Distributed Systems
# 13. Distributed Transactions
# 14. Networks - Links and Switches
# 15. Network Objects
# 16. Reliable messages and connection establishment
# 17. Availablility and Replication
# 18. Fault tolerance
# 19. Concurrent Caching
# 20. Computer Security in the Real World

# %% [markdown]
# - **Computer Systems I**
#     - Computer architecture evolution
#     - Digital electronics
#     - Computer arithmetic
#     - Assembly programming
#     - CPU structure
#     - RISC, Superscalar Architectures
#     - Buses and Interconnection
#     - Memory Systems and cache
#     - Input and Output. Interrupts
#     - Storage Systems and RAID
#     - Advanced architectures
#
#     - Texts:
#         - Tanenbaum AS, Structured Computer Organisation, Prentice Hall
#         - William Stallings, Computer Organisation and Architecture, 7th Edition, Prentice Hall, 2006

# %% [markdown]
# **Computation Structures** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-004-computation-structures-spring-2009/index.htm)
#
# 1.	Course overview and mechanics, basics of information
# 2.	Digital abstraction, combinational logic, voltage-based encoding
# 3.	CMOS technology, gate design, timing
# 4.	Canonical forms; synthesis, simplification
# 5.	Sequential logic
# 6.	Storage elements, finite state machines
# 7.	Synchronization, metastability
# 8.	Pipelining; throughput and latency
# 9.	Case study: multipliers	(PDF)
# 10.	Beta instruction set architecture, compilation
# 11.	Machine language programming issues
# 12.	Models of computation, programmable architectures
# 13.	Stacks and procedures
# 14.	Non-pipelined Beta implementation
# 15.	Multilevel memories; locality, performance, caches
# 16.	Cache design issues	(PDF)
# 17.	Virtual memory: mapping, protection, contexts
# 18.	Virtual machines: timesharing, OS kernels, supervisor calls
# 19.	Devices and interrupt handlers, preemptive interrupts, real-time issues
# 20.	Communication issues: busses, networks, protocols
# 21.	Communicating processes: semaphores, synchronization, atomicity, deadlock
# 22.	Pipelined Beta implementation, bypassing
# 23.	Pipeline issues: delay slots, annulment, exceptions
# 24.	Parallel processing, shared memory, cache coherence, consistency criteria
# 25.	Wrapup lecture
#
# - Text: [*A Student's Guide to the Digital World*] (http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-004-computation-structures-spring-2009/study-materials/MIT6_004s09_study_digital_guide.pdf)

# %% [markdown]
# - **Data Management**
#     - The Unix family of operating systems (Linux, BSD, OS X)
#         - The Unix philosophy and environment; files, processes, pipes, filters and basic utilities
#         - Data manipulation tools; editors, grep and other utilities.
#         - Scripting
#         - Shells and shell programming.
#         - Program development tools.
#     - Structured documents and markup languages
#         - LaTeX
#         - XML-based languages (HTML, DocBook)
#     - Database systems
#         - Rationale behind Database Systems
#         - Database Modelling using the Entity-Relationship Model
#         - Data Models and Data Sublanguages
#         - Practical SQL
#     - The Relational Model
#         - Relations, domains, attributes, keys, dependencies
#         - Normalisation
#
# - **Distributed Systems and Networks**
#     - Internet architecture
#         - The TCP/IP layered model
#         - Protocols, design principles, standardisation, IETF
#         - Naming and addressing
#     - Link-layer
#         - Transmission theory and protocols
#         - Ethernet networks, switches
#         - Wireless networks
#     - Network layer
#         - Routing, link state and distance vector algorithms
#         - Subnet, site and ISP routing perspectives
#         - IPv6
#     - Network services
#         - Quality of service (QoS)
#         - IP multicast, reliable multicast
#         - Host configuration, service discovery, zero-configuration networking
#         - DHCP, DNS
#     - Transport layer
#         - TCP, UDP
#     - Network design and operation
#         - Infrastructures; enterprise/campus, ISP/home networks
#         - Network monitoring and management, SNMP
#         - Virtual network environments
#     - Applications
#         - Web/HTTP, Email/SMTP
#     - Client-server programming
#         - Sockets
#     - Introduction to distributed systems
#         - Issues, challenges
#         - Distributed system models (architectural, interaction, failure, security)
#     - Time in distributed systems
#         - Clock synchronisation, logical clocks
#     - Distributed objects
#         - RPC/RMI
#         - Java RMI
#     - Distributed transactions
#     - Distributed algorithms
#         - Mutual exclusion
#         - Leader election
#         - Application of reliable/ordered multicast
#         - Consensus
#     - Indirect communication
#         - Group communication
#         - Publish-subscribe
#         - Message queues
#     - Web services
#         - The classic web service model; WSDL, SOAP, UDDI, RDF, XML
#         - RESTful  web services; HTTP methods, JSON
#         - (Linked) open data
#     - Peer to peer systems
#         - Design principles
#         - BitTorrent
#         - Distributed hash tables
#     - Network security
#         - Authentication and encryption, PKI
#         - (Distributed) denial of service attacks
#
# - Texts:
#      - Coulouris, Dollimore and Kindberg, Distributed Systems - Concepts and Design, 5th Edition, Addison Wesley 2011
#      - A Tanenbaum, D. J. Wetherall, Computer Networks, 5th Edition, Pearson, 2010
#      - Emmerich, W, Engineering Distributed Objects Wiley, 2000
#      - LL Peterson and BS Davie, Computer Networks, a Systems Approach, 4th Edition, Morgan Kaufman, 2008
