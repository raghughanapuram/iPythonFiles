# %% [markdown]
# ## Experiments in the Machine Interpretation of Visual Motion
# 1. Image, Scene, and Motion
#     - exegesis
#     - scene and image motion
#     - paradigms for computing visual motion
#     - visual versus projected motion
# 2. Computing Image Motion
#     - edgels as weak tokens
#     - an edgel matching algorithm
#     - The algorithm in detail
# 3. Structure of Motion of Points
#     - the aperature problem
#     - 3D constraints on the aperature problem
#     - point structure from known motion
#     - pointwise depths
#     - straight edges with known motion
# 4. The structure and motion of edges
#     - motion segmentation using edges
#     - the structure from motion algorithm
#     - computer experiments
#     - how many edges
# 5. From Edges to Surfaces
#     - imposing polyhedral constraints
#     - the polyhedral motion algorithm
# 6. Structure and Motion of Planes
#     - planar scenes
#     - recovering planar structure and motion
#     - planar facets with known motion
#     - 3D reconstructions: computer experiments
#     - failures of the planar facet algorithms
#     - reconstructing full visual motion
# 7. Visual motion segmentation
#     - global segmentation
#     - local segmentation
# 8. Matching to Edge Models
#     - model and data specification
#     - matching in overview
#     - the constraints in detail
#     - sign management within search
#     - location stage and testing global validity
# 9. Matching to Planar Surfaces
#     - the matching constraints
#     - location stage
# 10. Commentary
#     - sensing, perception and action
#     - representation
#     - computing motion and depth
#     - object recognition and location
#     - perception begets action
#     - dynamic vision
#     - reactive vision
#     - vision and control
#     - recognition
#     - shape and motion

# %% [markdown]
# ##Statistical and Geometrical Approaches to Visual Motion Analysis
# - **Optical Flow and Extensions**
#     1. discrete-continuous optimization for optical flow estimation
#     2. an improved algorithm for TV-L Optical Flow
#     3. An evaluation approach for scene flow with decoupled motion and position
#     4. an affine optical flow model for dynamic surface reconstruction
#     5. deinterlacing with motion-compensated anisotropic diffusion
# - **Human Motion Modeling**
#     1. real-time synthesis of body measurements based on learned primitives
#     2. 2D human pose estimation in TV shows
#     3. recognition and synthesis of human movements by parametric HMMs
#     4. recognizing human actions by their pose
# - **Biological and Statistical Approaches**
#     1. view-based approaches to spatial representation in human vision
#     2. combination of geometrical and statistical methods for visual navigation of autonomous robots
#     3. motion integration using competitive priors
# - **Alternative Approaches to Motion Analysis**
#     1. derivation of motion characteristics using affine shape adaptation for moving blobs
#     2. comparison and line features and their combination for rigid body motion estimation
#     3. the conformal monogenic signal of image sequences

# %% [markdown]
# ## Computer Vision Analysis of Image Motion by Variational Methods
# 1. Image Motion Processing in visual function
#     - image motion in visual function
#     - computer vision applications
#     - variational processing of image motion
# 2. background preliminaries
#     - curvature
#     - euler-lagrange equations
#     - differentiation under the integral sign
#     - descent methods for unconstrained optimization
#     - level sets
# 3. optical flow estimation
#     - the optical flow constraint
#     - the lucas-kanade algorithm
#     - the horn and schunck algorithm
#     - deriche-aubert-kornprobst method
#     - image-guided regularization
#     - minimum description length
#     - parametric estimation
#     - variations on the data and smoothness terms
#     - multiresolution and multigrid processing
#     - joint estimation and segmentation
#     - joint optical flow and disparity estimation
#     - state-of-the-art
# 4. motion detection
#     - background modelling and point-wise background subtraction
#     - variational background subtraction
#     - detection by image differencing
#     - optical flow based motion detection
#     - motion detection with a moving viewing system
#     - selective detection
#     - motion segmentation
# 5. tracking
#     - kernel-based tracking
#     - active curve density tracking
#     - tracking by region-based matching
#     - tracking in the spatiotemporal domain
# 6. optical flow three-dimensional interpretation
#     - projection models
#     - ego-motion in a static environment
#     - non-stationary environment
#     - scene flow

# %% [markdown]
# ## Guide to Three Dimensional Structure and Motion Factorization
# 1. Introduction to 3D computer vision
#     - imaging geometry and camera models
#     - single view metrology and reconstruction
#     - two-view geometry and 3D reconstruction
#     - reconstruction of structured scenes from two images
# 2. simplified camera projection models
#     - affine projection model
#     - quasi-perspective projection model
#     - experimental evaluations
# 3. geometrical properties of quasi-perspective projection
#     - one-view geometrical property
#     - two-view geometrical property
#     - 3D structure reconstruction
#     - evaluations of synthetic data
#     - evaluations on real images
# 4. introduction to strcture and motion factorization
#     - structure and motion factorization of rigid objects
#     - structure and motion factorization of nonrigid objects
#     - factorization of multi-body and articulated objects
# 5. perspective 3D reconstruction of rigid objects
#     - previous works on projective depths recovery
#     - hybrid projecive depths recovery
#     - camera calibration and euclidean reconstruction
#     - evaluations on synthetic data
#     - evaluations on real sequences
# 6. perspective 3D reconstruction of nonrigid objects
#     - perspective depth scales and nonrigid factorization
#     - perspective stratification
#     - evaluations on synthetic data
#     - experiments with real sequences
# 7. rotation constrained power factorization
#     - power factorization for rigid objects
#     - power factorization for nonrigid objects
#     - evaluations on synthetic data
#     - evaluations on real sequences
# 8. stratified euclidean reconstruction
#     - deformation weight constraint
#     - affine structure and motion recovery
#     - segmentation and stratification
# 9. quasi-perspective factorization
#     - background on factorization
#     - quasi-perspective rigid factorization
#     - quasi-perspective nonrigid factorization
# 10. Projective geometry for computer vision
#     - 2D projective geometry
#     - 3d projective geometry
# 11. Matrix decomposition
#     - singular value decomposition
#     - QR and RQ decompositions
#     - symmetric and skew-symmetric matrix
# 12. Numerical computation method
#     - linear least squares
#     - nonlinear estimation methods

# %% [markdown]
# ## Stereo Scene Flow for 3D Motion Analysis
# 1. Machine Vision Systems
# 2. Optical Flow Estimation
#     - optical flow and optical aperature
#     - feature-based optical flow approaches
#     - variational methods
#     - the flow refinement framework
# 3. Residual Images and Optical Flow Results
#     - increasing robustness to illumination changes
#     - quantitative evaluation of the refinement optical flow
#     - results for traffic scenes
# 4. Scene Flow
#     - visual kinesthesia
#     - formulation and solving of the constraint equations
#     - from image scene flow to 3D world scene flow
# 5. Motion Metric for Scene Flow
#     - ground truth vs. reality
#     - derivation of a pixel-wise accuracy measure
#     - residual motion likelihood
#     - speed likelihood
# 6. Extensions of Scene Flow
#     - flow cut - moving object segmentation
#     - kalman filters for scene flow vectors
# 7. Appendix: Data Terms and Quadratic Optimization
#     - optical flow constraint data term
#     - adaptive fundamental matrix constraint
#     - quadratic optimization via thresholding
# 8. Appendix: Scene Flow Implementation Using Euler-Lagrange Equations
#     - minimization of the scene flow energy
#     - implementation of scene flow

# %% [markdown]
# ##Motion and Structure from Image Sequences
# 1. Introduction
# 2. Image Matching
#     - approaches to establishing correspondences
#     - an approach to image matching
#     - algorithm
#     - motion and structure computation
# 3. Two-View analysis
#     - an algorithm
#     - error estimation
#     - error analysis
#     - performance
# 4. Optimization
#     - motivations
#     - stability of linear algorithms
#     - maximum likelihood estimation
#     - a two-step approach and computation
#     - minimum variance estimation
#     - error estimation and error bounds
#     - batch and sequential methods
#     - numerical examples
# 5. Planar Scenes
#     - planar scene as a degenerate case
#     - motion from a plane
#     - inherent uniqueness
# 6. From Line Correspondences
#     - lines as features
#     - solution and algorithm
#     - degeneracy
#     - optimization
# 7. Stereo
#     - stereo camera systems
#     - stereo triangulation
#     - closed-form solution
#     - iterative optimal solution
#     - outliers and robust estimators
#     - without stereo correspondences
#     - long image sequences
# 8. Motion Modeling and Prediction
#     - coherence of motion
#     - the LCAM model
#     - estimation and predication
#     - monocular vision
#     - optimization
#     - experimental examples
