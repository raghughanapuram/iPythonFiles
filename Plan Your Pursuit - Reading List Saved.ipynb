# %% [markdown]
# **Fundamentals of Electrical Engineering** [Don Johnson](http://www.ece.rice.edu/~dhj/) [Playlist](https://www.youtube.com/playlist?list=PLZ9qNFMHZ-A4yoVFeyZ_iIlGqlxm0r5g1)
#
# [Online textbook](http://cnx.org/contents/778e36af-4c21-4ef7-9c02-dae860eb7d14@9.71/Fundamentals_of_Electrical_Eng)
#
# 1. Introduction
# 2. Signals
# 3. Complex Numbers
# 4. Systems
# 5. Circuit Basics
# 6. Circuit Interconnection Laws
# 7. Equivalent Circuits
# 8. Circuits with Inductors and Capacitors
# 9. Circuits with Sinusoidal sources
# 10. Analog filters
# 11. Node Method and Conservation of Power
# 12. Operational Amplifiers
# 13. Fourier Series
# 14. Signals in the Frequency Domain
# 15. The Frequency Domain - The Entire Story
# 16. The Speech Signal
# 17. Decibels
# 18. Signal Acquisition by Computer
# 19. Discrete Time Signals and Systems
# 20. Discrete Time Spectral Analysis
# 21. Computing Spectra
# 22. Efficient Spectrum Calculation
# 23. Spectrograms
# 24. Digital Filters Time Domain
# 25. Digital Filters Frequency Domain

# %% [markdown]
# **Mathematics for Computer Science** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/video-lectures/)
#
# 1. Introduction and Proofs
# 2. Induction
# 3. Strong Induction
# 4. Number Theory I
# 5. Number Theory II
# 6. Graph Theory and Coloring
# 7. Matching Problems
# 8. Graph Theory II: Minimum Spanning Trees
# 9. Communication Networks
# 10. Graph Theory III
# 11. Relations, Partial Orders, and Scheduling
# 12. Sums
# 13. Sums and Asymptotics
# 14. Divide and Conquer Recurrences
# 15. Linear Recurrences
# 16. Counting Rules I
# 17. Counting Rules II
# 18. Probability Introduction
# 19. Conditional Probability
# 20. Independence
# 21. Random Variables
# 22. Expectation I
# 23. Expectation II
# 24. Large Deviations
# 25. Random Walks
#
# - Text: Lehman, et al. (2010) [*Mathematics for Computer Science*](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/readings/MIT6_042JF10_notes.pdf)
#
# **Great Ideas in Theoretical Computer Science** (Scott Aaronson) [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-080-great-ideas-in-theoretical-computer-science-spring-2008/)
#
# 1. Introduction
# 2. Logic
# 3. Circuits and finite automata
# 4. Turing machines
# 5. Reducibility and Godel
# 6. Minds and Macines
# 7. Complexity
# 8. Polynomial time
# 9. P and NP
# 10. NP-completeness
# 11. NP-completeness in practice
# 12. Space complexity and more
# 13. Randomness
# 14. Probabilistic complexity classes
# 15. Derandomization/cryptography double feature
# 16. Private-key cryptography
# 17. Public-key cryptography
# 18. Cryptographic protocols
# 19. Interactive proofs/machine learning
# 20. Probably Approximately Correct (PAC) Learning
# 21. Learning, Chomsky, RSA, quantum
# 22. Quantum computing
# 23. Quantum algorithms
#
# **Networks** [MIT OpenCourseware](http://ocw.mit.edu/courses/economics/14-15j-networks-fall-2009/)
#
# 1. Introduction to economic, social and communication networks
# 2. Graph theory and social networks
# 3. Branching processes and random graph models
# 4. Rich get rich phenomena, power laws, and small worlds
# 5. Epidemics and diffusion through networks
# 6. Introduction to game theory
# 7. Applications of game theory to networks
# 8. Evolution, learning, and myopia vs. rationality
# 9. Dynamic and repeated games, and cooperation and trust in networks
# 10. Network effects, innovation, tipping and contagion
# 11. Games of incomplete information
# 12. Social learning in networks
# 13. Decisions in groups
#
# - Texts:
#     - Easley, David, and Jon Kleinberg. *Networks, Crowds, and Markets: Reasoning about a Highly Connected World*. New York, NY: Cambridge University Press, 2010.
#     - Jackson, Matthew O. *Social and Economic Networks*. Princeton, NJ: Princeton University Press, 2008.

# %% [markdown]
# **Foundations of Computer Science**
#    - Mathematical proof
#         - Proof by case analysis, proof by contradiction.
#         - Induction and recursion.
#         - Universal properties.
#    - Sets, functions and relations
#         - Basic notation, representations and examples. Membership and subsets.
#         - Operations on sets: union, sum, intersection and complement.
#         - Pairs, tuples, cartesian products, powersets.
#         - Relations, equivalence relations and partial orders.
#         - Functions: injections, surjections, bijections.
#         - Cardinality, infinite sets.
#    - Logic
#         - Propositional logic. Logical connectives.
#         - Syntax and semantics.
#         - Natural deduction, soundness and completeness.
#         - Quantifiers and predicate logic.
#    - Combinatorics
#         - Basic principles of counting: product and sum rules, inclusion-exclusion principle, pigeonhole principle.
#         - Combinations, permutations and arrangements, binomial theorem.
#         - Introduction to trees and graphs: directed, undirected and weighted.    - Probability and statistics
#         - Introduction to probability: elementary probability formulae, discrete and continuous probability distributions.
#         - Introduction to statistics: sampling, confidence intervals, hypothesis testing, regression.
#    - Algebra
#         - Linear and quadratic equations, systems of equations.
#         - Polynomials: basic properties and operations.
#         - Vectors: basic properties, scalar product, vector product.
#         - Matrix algebra: basic properties, inverse, determinant, eigenvalues, eigenvectors, solving systems of linear equations.

# %% [markdown]
# ### MEng Electrical and Electronic Engineering [Page](http://www.ecs.soton.ac.uk/programmes/h602-meng-electrical-and-electronic-engineering#modules)

# %% [markdown]
# - **Electrical Materials and Fields**
#     - Basic Maths:
#         - Vectors: scalar product, vector product.
#         - Double integrals; polar integrals; triple integrals.
#         - Lines and planes; differentiation and integration of vectors.
#     - Electromagnetism
#         - Coulomb's Law.
#         - Electric field and flux.
#         - Potential.
#         - Potential gradient.
#         - Gauss' Law
#         - Moving charges and magnetic fields
#     - Passive devices
#         - Resistors (temp coefficient and noise)
#         - Power handling and dissipation
#         - Capacitors (polarised, hi-k, ultra-capacitor)
#         - Inductors
#         - Hysteresis and eddy currents
#         - Electromechanical devices:  electret microphones
#     - Oscillations and Waves
#         - Simple harmonic oscillation
#         - Coupled oscillators
#         - Wave equation
#         - Interference of waves
#         - Standing waves and resonance
#         - Transmissions lines
#         - Optical waveguiding
#         - Electromagnetic waves and the effect of permittivity
#     - Batteries and sustainability
#         - Batteries
#         - Fuel Cells
#
#     - Texts:
#         - Halliday D, Resnick, Walker, Fundamentals of Physics John Wiley
#         - Kasap S O, Principles of Electrical Engineering Materials and Devices, McGraw-Hill 1997
#         - Hammond P, Electromagnetism for Engineers- an introductory course, Fourth Edition, Oxford University Press, 1997
#         - Anderson J C, Lever K D, Alexander J M & Rawlings R D, Materials Science, 4th Edition, Chapman & Hall 1990
#
# - **Mathematics for Electronic and Electrical Engineering**
#     1. Complex numbers I: graphical representation of complex numbers; algebra of complex numbers; polar form of a complex number; Euler’s formula and exponential form of a complex number
#     2. Complex numbers II: relationships between trigonometric and hyperbolic functions; logarithm of a complex number; De Moivre’s theorem; the nth roots of a complex number; simple loci in the complex plane
#     3. Differentiation I: basic rules; differentiation of standard functions; Newton-Raphson procedure for finding roots; partial differentiation
#     4. Differentiation II: maxima, minima and points of inflection; curve sketching; parametric differentiation, implicit differentiation of functions of one variable and logarithmic differentiation; Taylor series, Maclaurin series
#     5. Functions: functions and inverse functions; trigonometric and inverse trigonometric functions; exponential and logarithmic functions; hyperbolic and inverse hyperbolic functions; differentiation of inverse trigonometric and hyperbolic functions
#     6. Integration I: definition of integra; standard integrals; use of simple substitutions; integration by parts; numerical integration
#     7. Integration II: use of substitution - further examples; applications of integration (volumes of revolution, centroids, centres of gravity, mean values, arclength and surface area)
#     8. Integration III: integration of rational functions; improper integrals
#     9. Integration IV: double integration; polar coordinates; triple integration
#     10. Vectors I: scalars, vectors and notation; addition and subtraction of vectors; cartesian components of a vector; scalar product of two vectors and applications; vector product of two vectors and applications
#     11. Vectors II: triple scalar product and triple vector product; differentiation and integration of vectors; vector equation of a line; vector equation of a plan
#     12. Matrices I: terminology; addition, subtraction and multiplication of matrices; determinants
#     13. Matrices II: inverse of matrix using cofactors; sets of linear equations; solution of sets of linear equations using elimination method; inverse of matrix using elimination method
#     14. Matrices III: rank; eigenvalues and eigenvectors
#     15. Differential Equations I: classification of differential equations; first order separable ordinary differential equations; second order linear homogeneous ordinary differential equations with constant coefficients
#     16. Differential Equations II: first order ordinary differential equations of the type dx/dt = f(x/t); exact first order ordinary differential equations; linear first order ordinary differential equations; applications
#     17. Differential Equations III: linear operators; linear inhomogeneous second order ordinary differential equations with constant coefficients; free and forced oscillations
#     18. Fourier series: periodic signals; whole-range Fourier series; even and odd functions
#     19. Laplace Transforms: definition; Laplace transform of standard functions; inverse Laplace transforms; solution of second order linear ordinary differential equations with constant coefficients
#     20. Further Calculus: chain rule for partial derivatives; higher partial derivatives; total differentials and small errors
#
# - **Digital Systems and Signal Processing**
#
# - **Mathematics for Electronic and Electrical Engineering Part II**
#     - Laplace transform theory.
#         - Use of Laplace transforms in solving simple ODEs with constant coefficients and given boundary conditions. Step functions and their transforms. Laplace transforms of standard functions. Elementary properties – linearity, first and second shifting theorems, change of scale. Transforms of derivatives, integrals and of products with powers of t. Transforms of periodic functions.
#     - Eigenvalues, eigenvectors and eigenfunctions
#         - Matrix eigenvalue problems. Examples of Sturm-Liouville problems. Sturm-Liouville Theory. Fourier series representation of a function in terms of solutions to Sturm-Liouville problem.
#     - Fourier analysis
#         - Fourier Series. Fourier transforms. Discrete Fourier transforms.
#     - Partial differential equations
#         - Classification of second-order linear PDEs. The technique of separation of variables with particular application to the wave equation.

# %% [markdown]
# **Slotine Lectures on Nonlinear Systems** [Lectures](http://web.mit.edu/nsl/www/videos/lectures.html)
#
# 1. Introduction
# 2. Basic Lyapunov Theory
# 3. Lyapunov Stability Analysis
# 4. Convergence to Invariant Sets
# 5. Stability of Time-Varying Systems
# 6. Sliding Variables
# 7. Robust Control
# 8. Adaptive Control
# 9. Robust Adaptive Control
# 10. Adaptive Robot Control
# 11. Feedback Linearization
# 12. Basic Differential Geometry Tools
# 13. Controllability, Integrability, Backstepping
# 14. Introduction to Contraction Analysis
# 15. Basic Results in Contraction Analysis
# 16. Combinations of Contracting Systems
# 17. Virtual Systems
# 18. Synchronization
# 19. Stable Invariant Subspaces, Polyrhythms
# 20. How Synchronization Protects from Noise
#
# - Text: *Applied Nonlinear Control*, Slotine and Li, 1991

# %% [markdown]
# **Learning to Learn** Richard Hamming [Videos](https://www.youtube.com/playlist?list=PL2FF649D0C4407B30)
#
# 1. Introduction to the Art of Doing Science and Engineering: Learning to Learn
# 2. Foundations of the Digital (Discrete) Revolution
# 3. History of Computers - Hardward
# 4. History of Computers - Software
# 5. History of Computers - Applications
# 6. Artificial Intelligence - Part I
# 7. Artificial Intelligence - Part II
# 8. Artificial Intelligence - Part III
# 9. n-Dimensional Space
# 10. Coding Theory - The Representation of Information - Part I
# 11. Coding Theory - The Representation of Information - Part II
# 12. Error-Correcting Codes
# 13. Information Theory
# 14. Digital Filters
# 15. Simulation
# 16. Fiber Optics
# 17. Computer Aided Instruction
# 18. Mathematics
# 19. Quantum Mechanics
# 20. Creativity
# 21. Experts
# 22. Unreliable Data
# 23. Systems Engineering
# 24. You Get What you Measure
# 25. How Do We Know What We Know?
# 26. You and Your Research

# %% [markdown]
#
#
#
# - **Bioinformatics: Network Analysis** [page](http://www.cs.rice.edu/~nakhleh/COMP572/#info)
#     1. Networks in biology
#     2. Molecular cell biology: A review
#     3. Modeling in biology
#     4. Graph-theoretic properties
#     5. Graph-theoretic properties of biological netorks
#     6. Discrete dynamic modeling: Boolean networks and Petri nets
#     7. Reaction kinetics
#     8. Enzyme kinetics
#     9. Kinetics of gene regulation
#     10. Kinetics of regulatory networks: Basic building blocks
#     11. Analyses of biological systems models
#     12. Probabilisitc modeling: Bayesian networks
#     13. Analyzing stoichiometics matrices
#     14. Flux-balance analysis (FBA) and metabolic control analysis (MCA)
#     15. Model fitting
#     16. Network motifs
#     17. Evolution of genes and genomes
#     18. Comparative network analysis
#     19. Networks as a guiding tool
#
# - **Bioinformatics: Sequence Analysis** [page](http://www.cs.rice.edu/~nakhleh/COMP571/)
#     1. Background material
#     2. Sequence alignment: General overview
#     3. Sequence analysis: Scoring schemes
#     4. Sequence analysis: Dynamic programming algorithms for pairwise alignment
#     5. Significance of estimated sequence alignments
#     6. Markov chains and hidden Markov models
#     7. Pairwise HMMs and sequence alignments
#     8. Profiles and multiple sequence alignments
#     9. Phylogenetics: Recovering Evolutionary Theory
#     10. Phylogenetics: building Phylogenetic Trees
#     11. Phylogenetics: Distance-Based Methods
#
# - **Bioninformatics: Sequence Analysis/Population Genetics** [page](http://www.cs.rice.edu/~nakhleh/COMP571/)
#     1. Background material
#     2. Mathematical/computational techniques
#     3. Genotype frequencies
#     4. Genetic drift and effective population size
#     5. Population structure and gene flow
#     6. Mutation
#     7. Natural selection
#     8. Molecular evolution
#     9. Sequence alignment: general overview
#     10. Sequence alignment: Scoring schemes
#     11. Pairwise sequence alignment: Dynamic programming algorithms
#     12. Pairwise sequence alignmnet: HMMs and statistical significance
#     13. Multiple sequence alignment
#     14. Phylogenetics: Recovering Evolutionary Theory
#     15. Phylogenetics: Building phylogenetic trees
#     16. Phylogenetics: Theory and algorithms
#
# - **Complex Systems Seminar I** [page](http://www.informatics.indiana.edu/rocha/icx1/)
#     - **Part I: History of the Field**
#         1. Cybernetics and the Informational Turn
#             - Borges, Jorge Luis. [1941]. The Library of Babel.
#             - Borges, Jorge Luis. [1941]. The Garden of Forking Paths .
#             - Brenner, Sydney. [2012]. "History of Science. The Revolution in the Life Sciences". Science 338 (6113): 1427–8.
#             - Brenner, Sydney. [2012]. "Turing centenary: Life’s code script.” Nature 482 (7386) (February 22): 461-461.
#             - Cobb, Matthew. [2013]. "1953: When Genes Became ‘Information’." Cell 153 (3): 503–506.
#             - Gleick, J. [2011]. The Information: A History, a Theory, a Flood. Random House. Chapter 8.
#             - Heims, S.G. [1991]. The Cybernetics Group. MIT Press. Chapters: 1,2, 11, and 12.
#             - McCulloch, W. and W. Pitts [1943], "A Logical Calculus of Ideas Immanent in Nervous Activity". Bulletin of Mathematical Biophysics 5:115-133.
#             - Nature|Comment [2012] "Turing Centenary: Is the Brain a Good Model for Machine Intelligence?." Nature 482 (7386): 462–463.
#             - Searls, David B. [2010]. "The Roots of Bioinformatics". PLoS Computational Biology 6(6): e1000809.
#             - Witzany, Günther, and František Baluška. [2012]. "Life’s Code Script Does Not Code Itself. The Machine Metaphor for Living Organisms Is Outdated". EMBO Reports 13 (12): 1054–6.
#         2. Systems Science, Prediction, and Limits
#             - Ashby, W.R.[1956]. An Introduction to Cybernetics, Chapman & Hall, London, Chapter 1. Full book available electronically. (Alternative Location)
#             - Hilbert, M., and P. Lopez. [2011]. "The World’s Technological Capacity to Store, Communicate, and Compute Information." Science 332 (6025): 60–65. doi:10.1126/science.1200970. ]
#             - Klir, G.J. [2001]. Facets of systems Science. Springer. Chapters: 1,2,3, 8, and 11.
#             - Rosen, R. [1986]. "Some comments on systems and system theory". Int. J. of General Systems, 13: 1—3.
#             - Von Foerster, H., P. M. Mora and L. W. Amiot [1960]. "Doomsday: Friday, November 13, AD 2026." Science 132:291–1295.
#             - Weaver, W. [1948]. "Science and Complexity". American Scientist, 36(4): 536-44. (PMID: 18882675)
#         3. Self-Organizing Systems
#             - Ashby, W.R.[1962]. "Principles of the self-organizing system". In: Principles of Self-Organization: Transactions of the University of Illinois Symposium. H. Von Foerster and G. W. Zopf, Jr. (eds.), Pergamon Press: London, UK, pp. 255-278.
#             - Cariani, P. [1992]. "Some epistemological implications of devices which construct their own sensors and effectors". In: Towards a Practice of Autonomous Systems.In F. Varela and P. Bourgine (ed.), MIT Press, Cambridge, Massachusetts.
#             - Cariani, P. [1993]. "To evolve an ear. Epistemological implications of gordon pask's electrochemical devices". Systems Research, 10(3):19-33.
#         4. Second-Order Cybernetics
#             - Cariani P. [2009]. "On the Importance of Being Emergent. Extended Review of “Emergence and Embodiment: New Essays on Second-Order Systems Theory” edited by Bruce Clark and Mark B. N. Hanson.Duke University Press, Durham, 2009. Constructivist Foundations. 5(2):86-91.
#             - Pask, G. [1992]. "Different kinds of Cybernetics". In: New Perspectives on Cybernetics. G. Van de Vijver (Ed.), Kluwer Academic Publishers. pp. 11-31.
#             - Rocha, Luis M. [1996]. "Eigenbehavior and Symbols". Systems Research, 13(3):371-384.
#             - Varela, Francisco J.; Maturana, Humberto R.; & Uribe, R. [1974]. "Autopoiesis: the organization of living systems, its characterization and a model". Biosystems 5(4): 187-196.
#             - Varela, F.J. [1996]. "The early days of autopoiesis". Systems Research, 13(3):407-416.
#             - Varela, F.J. [1997]. "Patterns of Life: Intertwining Identity and Cognition". Brain and Cognition, 34(1):72-87.
#             - Optional: Von Foerster, H. [1970]. "Molecular Ethology, an Immodest Proposal for Semantic Clarification". In Molecular Mechanisms in Memory and Learning, Georges Ungar (Hg.), Plenum Press, New York, pp. 213–248.
#             - Optional: Von Foerster, H. [1993]. "On Gordon Pask". Systems Research, 10(3):35-42.
#         5. Organization of Complex Systems
#             - Jaimovich, A., R. Rinott, M. Schuldiner, H. Margalit, and N. Friedman. 2010. "Modularity and directionality in genetic interaction maps". Bioinformatics 26 (12): i228-i236. doi:10.1093/bioinformatics/btq197.
#             - Lazebnik, Y [2002]. "Can a biologist fix a radio?--Or, what I learned while studying apoptosis". Cancer Cell, 2(3):179-182.
#             - Pattee, H.H. [1973]. "The Physical Basis and Origin of Hierarchical Control". In: Hierarchy Theory: The Challenge of Complex Systems. H.H. Pattee (ed.) , New York: G. Braziller, pp.73-108.
#             - Prigogine, I. [1985]. "New Perspectives on Complexity". In: The Science and Praxis of Complexity (United Nations University Press: 1985) 107-118
#             - Optional: Randall, T.S. [2007]. "Robert Rosen in the Age of Systems Biology". Chemistry & Biodiversity, 4(10):2407 - 2414.
#             - Rosen, R. [1986]. "The Physics of Complexity". Systems Research, 2: 171.
#             - Rosen, R. [1987]. "On Complex Systems". European Journal of Operational Research, 30: 129-134.
#             - Simon, H.A. [1962]. "The Architecture of Complexity". Proceedings of the American Philosophical Society, 106: pp. 467-482.
#     - **Part II: Current Research**
#         1. Towards a practice of Complex Systems
#             - Clauset, A., C. R. Shalizi, and M. E. J. Newman. [2009]. "Power-Law Distributions in Empirical Data". SIAM Review 51 (4): 661–703. doi:10.1137/070710111.
#             - Coutinho, A. [2003]. "On doing science: a speech by Professor Antonio Coutinho". Economia, 4(1): 7-18, jan./jun. 2003.
#             - Feynman, R. [1974]. "Cargo Cult Science", Caltech commencement address.
#             - Klir, George J. [1985]. "Complexity: Some General Observations." Systems Research 2 (2): 131–140.
#             - McShea, D. W. [2013]. "Unnecessary Complexity." Science 342 (6164): 1319–1320. See also Comments by Melanie Mitchell.
#             - Pattee, H.H. [2007]. "Laws, Constraints, and the Modeling Relation - History and Interpretations". Chemistry & Biodiversity, 4(10):2272-2295.
#             - Sandve, Geir Kjetil, Anton Nekrutenko, James Taylor, and Eivind Hovig. [2013]. "Ten Simple Rules for Reproducible Computational Research." PLoS Computational Biology 9 (10): 4.
#             - Shalizi, C. R. [2007]. "So You Think You Have a Power Law — Well Isn’t That Special?". Three-Toed Sloth Blog.
#             - Schwartz, M.A. [2008]. "The importance of stupidity in scientific research". Journal of Cell Science, 121: 1771.
#             - Theise, N.D., and M.C. Kafatos. [2013]. "Complementarity in Biological Systems: A Complexity View." Complexity 18 (6): 11–20.
#             - West, G. [2013]. "Wisdom in Numbers." Scientific American 308 (5): 14.
#             - Wolpert, D.H. [2012]. "What the No Free Lunch Theorems Really Mean; How to Improve Search Algorithms." Santa Fe Institute Working Paper.
#             - Zhang, W. [2014]. "Ten Simple Rules for Writing Research Papers." PLoS Computational Biology 10 (1): e1003453.
#         2. Evolutionary Systems
#             - Clune, J., J.-B. Mouret, and H. Lipson. [2013]. "The Evolutionary Origins of Modularity." Proceedings of the Royal Society B: Biological Sciences. 280 (1755): 20122863–20122863.
#             - Conrad, M. [1990]. "The geometry of evolution.". Biosystems 24: 61-81
#             - Draghi JA, Parsons TL, Wagner GP, Plotkin JB [2010]. "Mutational robustness can facilitate adaptation.". Nature 463 (7279):353-5
#             - Hordijk, Wim. [2013] "The EvCA Project: A Brief History." Complexity:doi:10.1002/cplx.21445.
#             - Pennisi, E. [2013]. " The Man Who Bottled Evolution." Science 342 (6160): 790–793.
#             - Pigliucci M. [2008]. "Is evolvability evolvable?". Nature reviews. Genetics. 9 (1): 75-82
#             - Pigliucci, M. [2013]. "Between Holism and Reductionism: A Philosophical Primer on Emergence." Biological Journal of the Linnean Society doi:10.1111/bij.12060.
#             - Rocha LM, Hordijk W. [2005]. "Material representations: From the genetic code to the evolution of cellular automata.". Artificial Life. 11(1-2):189-214.
#             - Vasas, Vera, Eors Szathmary, and Mauro Santos [2010]. " Lack of evolvability in self-sustaining autocatalytic networks: A constraint on the metabolism-first path to the origin of life. ". Proceedings of the National Academy of Sciences of the United States of America: 0912628107.
#             - Weiss, R. A., and J. P. Stoye. [2013]. "Our Viral Inheritance." Science 340 (6134): 820–821.
#             - Wang, Jin, Kun Zhang, Li Xu, and Erkang Wang. [2011]. “Quantifying the Waddington landscape and biological paths for development and differentiation.” Proceedings of the National Academy of Sciences of the United States of America 108 (20): 8257-8262.
#         3. Information and Complexity
#             - Adamic, Lada A., Thomas M. Lento, Eytan Adar, and Pauline C. Ng. [2014]. "Information Evolution in Social Networks”. arXiv:1402.6792
#             - Auerbach, Joshua E., and Josh C. Bongard. [2014]. "Environmental Influence on the Evolution of Morphological Complexity in Machines." PLoS Computational Biology 10 (1): e1003399.
#             - Clark, Andy. [2013]. "Whatever next? Predictive Brains, Situated Agents, and the Future of Cognitive Science." The Behavioral and Brain Sciences 36 (3): 181–204.
#             - Crutchfield, James, and Karl Young. [1989]. “Inferring statistical complexity.” Physical Review Letters 63 (2): 105-108.
#             - Gell-Mann, Murray, and Seth Lloyd. [1996]. “Information measures, effective complexity, and total information.” Complexity 2 (1): 44-52.
#             - James, R.G., K.Burke, and J.P. Crutchfield. [2013]. "Chaos Forgets and Remembers: Measuring Information Creation, Destruction, and Storage". arXiv:1309.5504.
#             - Klir, George J. [2006.] Uncertainty and information: Emergence of vast new territories. In Systemics of Emergence: Research and Development, ed. Gianfranco Minati, Eliano Pessa, and Mario Abram, 3-28. New York: Springer-Verlag.
#             - McAllister, James W. [2003]. “Effective Complexity as a Measure of Information Content.” Philosophy of Science 70 (2): 302-307. doi:10.1086/375469.
#             - Prokopenko, Mikhail, Fabio Boschetti, and Alex J. Ryan. [2009]. "An information-theoretic primer on complexity, self-organization, and emergence. ". Complexity 15(1): 11-28
#             - Tenenbaum, J. B., C. Kemp, T. L. Griffiths, and N. D. Goodman. [2011]. “How to Grow a Mind: Statistics, Structure, and Abstraction.” Science 331 (6022): 1279-1285.
#         4. Neo-Cybernetics themes
#             - Amaral, Paulo P, Marcel E Dinger, Tim R Mercer, and John S Mattick. 2008. “The eukaryotic genome as an RNA machine.” Science. 319 (5871): 1787-9.
#             - Helbing, Dirk, Dirk Brockmann, Thomas Chadefaux, Karsten Donnay, Ulf Blanke, Olivia Woolley-Meza, Mehdi Moussaid, et al. [2014]. "How to Save Human Lives with Complexity Science". arXiv:1402.7011.
#             - Jones, Nicola. [2014]. "Computer Science: The Learning Machines." Nature 505 (7482): 146–148. doi:10.1038/505146a.
#             - Klamt S, Haus U-U, Theis F. [2010]. "Hypergraphs and cellular networks.". PLoS computational biology 5(5): e1000385
#             - Szathmáry, Eörs, and Szabolcs Számadó. [2008]. “Being human: language: a social history of words.” Nature 456 (7218): 40-1.
#             - Varol, Onur, and Filippo Menczer. [2014]. "Connecting Dream Networks Across Cultures". arXiv.

# %% [markdown]
#
# - **Biologically inspired computing** [page](http://www.informatics.indiana.edu/rocha/i-bic/)
#     1. What is Life?
#         - What is so cool about life?
#         - Life and Information
#         - The Logical Mechanisms of Life
#     2. Imitation of Life
#         - Computational Beauty of Nature
#         - Self-similarity: fractals, L-systems, chaos
#     3. Life as (Self-)Organization
#         - Artificial Life, Complex Systems and Complex Networks
#         - Self-Organization and Emergent Complex Behavior
#         - Cellular Automata
#         - Boolean Networks
#         - Development and Morphogenesis
#     4. What is Computation?
#         - What is so cool about computation?
#         - Universal Computation and Life
#     5. Life as Evolution of Turing Machines
#         - Von Neuman, Self-Replication and Open-ended evolution
#         - Evolution and Adaptation
#         - Biology through the lens of computer science
#         - Genetic and Evolutionary Algorithms
#         - Genetic Programming
#         - Evolutionary Robotics
#     6. Collective Behavior and Swarm Intelligence
#         - Social Insects, Stigmergy and Swarm Intelligence
#         - Communication and Multi-Agent simulation
#         - Collective Computation and the Extended Mind
#     7. Immunocomputing
#         - A distributed design for computational intelligence
#         - Multi-level complexity
#         - Engineering Applications
#
#
#
# - ** Differential Equations ** [page](http://ocw.mit.edu/courses/mathematics/18-03sc-differential-equations-fall-2011/index.htm)
#     - ** I. First Order Differential Equations**
#         1. Conventions
#         2. Basic DE's
#         3. Geometrical methods
#         4. Numerical methods
#         5. Linear ODEs
#         6. Integrating Factors
#         7. Complex Arithmetic
#         8. Sinusoidal Functions
#         9. Constant Coefficients
#         10. Exponential Input
#         11. Autonomous Equations
#         12. Linear vs. Nonlinear
#     - ** II. Second Order Constant Coefficient Linear Equations**
#         1. Characteristic Equation
#         2. Damped Oscilators
#         3. Exponential Response
#         4. Gain and Phase Lag
#         5. Undetermined Coefficients
#         6. Linear Operators
#         7. Pure Resonance
#         8. Frequency Response
#     - ** III. Fourier Series and Laplace Transform**
#         1. Fourier Series: Basics
#         2. Operations
#         3. Step and Delta
#         4. Impulse Response
#         5. Convolution
#         6. Laplace Transform
#         7. Partial Fractions
#         8. Solving IVPs
#         9. Transfer Funtions
#         10. Poles
#     - ** IV. First-Order Systems **
#         1. Linear Systems
#         2. Matrix Methods
#         3. Phase Portraits
#         4. Matrix Exponentials
#         5. Nonlinear Systems
#         6. Linearization
#         7. Limit Cycles and Chaos
#
# - **Classic Control Theory** [videos](https://www.youtube.com/playlist?list=PLUMWjy5jgHK1NC52DXXrriwihVrYZKqjk)
#     1. Why Learng Control Theory?
#     2. Closed Loop Control
#     3. Time and Frequency Domain
#     4. LTI Systems
#     5. Transfer Functions
#     6. Introduction to the Fourier Transform
#     7. The Laplace Transform - A Graphical Approach
#     8. Bode Plots, Introduction
#     9. Real Constants
#     10. Poles and Zeros at the Origin
#     11. Real Poles or Zeros
#     12. Complex Poles or Zeros
#     13. Final value Theorem and Steady State Error
#     14. Introduction to System Stability and Control
#     15. Stability of Closed Loop Control Systems
#     16. Routh-Hurwitz Criterion, An Introduction
#     17. Routh-Hurwitz Criterion, Special Cases
#     18. Routh-Hurwitz Criterion, Beyond Stability
#     19. The Root Locus Method - Introduction
#     20. Sketching Root Locus
#     21. Nyquist Stability Criterion
#     22. PID Control - A brief introduction
#     23. Simple Examples of PID Control
#     24. Gain and Phase Margins Explained!
#     25. Understanding the Sensitivity Function
#     26. What are Lead Lag Compensators?
#     27. Designing a Lead Compensator with Root Locus
#     28. Designing a Lead Compensator with Bode Plot
#     29. Designing a Lag Compensator with Root Locus
#     30. Designing a Lag Compensator wih Bode Plot
#     31. Modeling Physical Systems, and Overview
#     32. System Identification Methods
#     33. Robotic Car, Closed Loop Control Example
#     34. Robotic Car - A Simple Way to Build a Model
#     35. Robotic Car - How to read Gyro datasheets
#     26. Controlling Robotic Swarms
#
# - ** Mathematical Exposition ** [page](http://ocw.mit.edu/courses/mathematics/18-091-mathematical-exposition-spring-2005/)
#     1. Examples of Dynamical Systems; Chaos
#     2. Mathematica Lab
#     3. Graphical Analysis of Orbits; Fied and Periodic Points
#     4. Bifurcations
#     5. Writing Feedback
#     6. The Quadratic Familt
#     7. Transition to Chaos
#     8. Symbolic Dynamics
#     9. Chaos
#     10. Sarkovskii's Theorem
#     11. The Role of Critical Orbit
#     12. Newton's Method; Fractals
#
# - **Linear Algebra** [page](http://ocw.mit.edu/courses/mathematics/18-06sc-linear-algebra-fall-2011/)
#     - **I. AX = B and the Four Subspaces**
#         1. The Geometry of Linear Equations
#         2. An Overview of Key Ideas
#         3. Elimination with Matrices
#         4. Multiplication and Inverse Matrices
#         5. Factorization into A = LU
#         6. Transposes, Permutations, Vector Spaces
#         7. Column Space and Nullspace
#         8. Solving AX=0; Pivot Variables and Special Solutions
#         9. Solving AX = B; Row Reduced Form R
#         10. Independence, basis and dimensions
#         11. The Four Fundamental Subspaces
#         12. Matrix Spaces; Rank 1: Small-World Graphs
#         13. Graphs, Networks, Incidence Matrices
#     - **II. Least Squares, Determinants, and Eigenvalues**
#         1. Orthogonal Vectors and Subspaces
#         2. Projections onto Subspaces
#         3. Projection Matrices and Least Squares
#         4. Orthogonal Matrices and Gram-Schmidt
#         5. Properties of Determinants
#         6. Determinant Formulas and Cofactors
#         7. Cramer's Rule, Inverse Matrix and Volume
#         8. Eigenvalues and Eigenvectors
#         9. Diagonalization and Powers of A
#         10. Differential Equations and EXP(AT)
#         11. Markov Matrices, Fourier Series
#     - ** III. Positive Definite Matrices and Applications**
#         1. Symmetric Matices and Positive Definiteness
#         2. Complex Matrices; Fast Fourier Transform (FFT)
#         3. Positive Definite Matrices and Minima
#         4. Similar Matrices and Jordan Form
#         5. Singular Value Decomposition
#         6. Linear Transformations and their Matrices
#         7. Change of Basis; Image Compression
#         8. Left and Right Inverses; Pseudoinverse
#
# - **Mathematics for Computer Science** [page](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-042j-mathematics-for-computer-science-fall-2010/index.htm)
#     - **I. Proofs**
#         1. Propositions
#         2. Patterns of proof
#         3. Induction
#         4. Number Theory
#     - **II. Structures**
#         1. Graph theory
#         2. Directed graphs
#         3. Relations and partial orders
#         4. State machines
#     - **III. Counting**
#         1. Sums and asymptotics
#         2. Recurrences
#         3. Cardinality rules
#         4. Generating functions
#         5. Infinite sets
#     - **IV. Probability**
#         1. Events and probability spaces
#         2. Conditional probability
#         3. Independence
#         4. Random variables and distributions
#         5. Expectation
#         6. Deviations
#         7. Random walks
#
# - **Multivariate Calculus** [page](http://ocw.mit.edu/courses/mathematics/18-02sc-multivariable-calculus-fall-2010/)
#     - **I. Vectors and Matrices**
#         - Vectors, determinants, and planes
#         - Matrices and systems of equations
#         - Parametric equations for curves
#     - **II. Partial Derivatives**
#         - Functions of two variables, tangent approximation and opt
#         - Chain rule, gradient and directional derivatives
#         - Lagrange multipliers and constrained differentials
#     - ** III. Double Integrals and Line Integrals in the Plane**
#         - double integrals
#         - vector fields and line integrals
#         - green's theorem
#     - **IV. Triple Integrals and Surface Integrals in 3-Space**
#         - triple integrals
#         - flux and the divergence theorem
#         - line integrals and stoke's theorem
#
# - **Introduction to Partial Differential Equations** [page](http://ocw.mit.edu/courses/mathematics/18-152-introduction-to-partial-differential-equations-fall-2011/index.htm)
#     1. Introduction to PDEs
#     2. Introduction to the heat equation
#     3. The heat equation: uniqueness
#     4. The heat equation: Weak maximum principle an introduction to the fundamental solution
#     5. The heat equation: Fundamental solution and the global Cauchy problem
#     6. Laplace's and Poisson's equations
#     7. Poisson's equation: Fundamental solution
#     8. Poisson's equation: Green's functions
#     9. Poisson's equation: Poisson's formula, Harnack's inequality, and Liouville theorem
#     10. Introduction to the wave equation
#     11. The wave equation: the method of spherical means
#     12. The wave equation: Kirchoff's formula and Minkowskian geometry
#     13. The wave equation: Geometric energy estimates
#     14. Classification of second order equations
#     15. Introduction to the Fourier transform
#     16. Fourier inversion and Plancherel's theorem
#     17. Introduction to Schrodinger's equation
#     18. Introduction to Lagrane field theories
#     19. Transport equations and Burder's equation

# %% [markdown]
#
# - **Introduction Computational Physics** [page](http://astro.physics.ncsu.edu/urca/course_files/)
#     1. Introduction to the course, computing facilities, Python
#     2. Python basics, arrays, plotting
#     3. Numerical solution to ODEs; A first stab at programming
#     4. Test your code!; Accuracy and efficiency
#     5. Numerical Error
#     6. Supersonic freefall: another ODE example
#     7. Using latex to express yourself
#     8. Root-finding
#     9. Linear Algebra I
#     10. Linear Algebra II
#     11. Numerical Integration I
#     12. Numerical Integration II
#     13. Data Fitting
#     14. A simple pendulum. What could go wrong?
#     15. What could a little damping do? Chaos!
#     16. Phase Space
#     17. Period Doubling, In and out of Chaos
#     18. Frequency analysis, Fourier Transforms
#     19. FFTs, Power Spectra
#     20. Random Processes, Monte Carlo Integration
#     21. Monte Carlo Methods, Random Walks
#     22. Ising Model
#     23. Phase Transitions I
#     24. Phase Transitions II
#     25. Boundary value problems
#     26. Wave equation, finite difference method
#     27. Waves: reflection and transmission
