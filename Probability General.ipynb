# %% [markdown]
# **Random Signals** [Justin Romberg](http://users.ece.gatech.edu/justin/Justin_Romberg.html) [Course Page](http://users.ece.gatech.edu/~justin/ECE-3075-Fall-2008/Overview.html)
#
# 1. Review of basic probability
#     - set theory and axiomatic theory
#     - conditional probability and Bayes Theorem
#     - combinatorics
#     - Bernoulli trials
# 2. Review of basic random variables
#     - expectation and moments
#     - Gaussian random variables
#     - Rayleigh distribution
#     - conditional probability and exponential random variables
#     - joint distributions
#     - conditional likelihood
#     - statistical independence and correlation
#     - the moment generating function; adding two independent random variables
#     - functions of two random variables
# 3. Introduction to estimation
#     - estimating the mean and variance
#     - the maximum likelihood estimator (MLE) and maximum a posterior estimator (MAP)
#     - hypothesis testing
# 4. Gaussian random vectors
#     - jointly Gaussian random vectors (GRVs)
#     - conditional pdfs for GRVs
#     - minimum mean-square error (MMSE) prediction
#     - the non-Gaussian case: optimal linear estimators
# 5. Random processes
#     - stationary, wide-sense stationary, and ergodic process
#     - the autocorrelation function
#     - review of linear time-invariant systems (LTI systems)
#     - wide-sense stationary processes and LTI systems
#     - power-spectral density
#     - filtering out noise
#     - basic linear prediction
#     - introduction to spectral estimation
#     - Poisson and point processes
#
# - Texts:
#     - Cooper and McGillem, *Probabilistic Methods of Signal and System Analysis*
#     - Feller, *An Introduction to Probability Theory and its Applications*
#     - Stark and Woods, *Probability, Random Processes, and Estimation Theory for Engineers*
#     - Papoulis and Pillai, *Probability, Random Variables, and Stochastic Processes*
#     - P. Bernstein, *Against the Gods: The Remarkable Story of Risk*
#     - L. Mlodinow, *The Drunkard’s Walk: How Randomness Rules Our Lives*

# %% [markdown]
# **Probabilistic Systems Analysis and Applied Probability** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-041sc-probabilistic-systems-analysis-and-applied-probability-fall-2013/index.htm)
#
# 1. Probability Models and Discrete Random Variables
#     1. Probability Models and Axioms
#     2. Conditioning and Baye's Rule
#     3. Independence
#     4. Counting
#     5. Discrete Random Variables: Probability Mass Functions: Expectations
#     6. Discrete Random Variables Examples: Joint PMFs
#     7. Multiple Discrete Random Variables
# 2. General random variables
#     1. Continuous Random Variables
#     2. Multiple Continuous Random Variables
#     3. Continuous Bayes' Rule: Derived Distributions
#     4. Derived Distributions: Convolution; Covariance and Correlation
#     5. Iterated Expectations: Sum of a Random Number of Random Variables
# 3. Random Processes
#     1. Bernoulli Process
#     2. Poisson Process - I
#     3. Poisson Process - II
#     4. Markov Chains - I
#     5. Markov Chains - II
#     6. Markov Chains - III
# 4. Laws of Large Numbers and Inference
#     1. Weak Law of Large Numbers
#     2. Central Limit Theorem
#     3. Bayesian Statistical Inference
#     4. Bayesian Statistical Inference II
#     5. Classical Inference I
#     6. Classical Inference II
#     7. Classical Inference III
#
# - Text: Bertsekas, *Introduction to Probability*

# %% [markdown]
# - **Probability and Random Variables** [page](http://ocw.mit.edu/courses/mathematics/18-440-probability-and-random-variables-spring-2011/index.htm)
#
#     1. Permutations
#     2. Mulinomial coefficients and more counting
#     3. Sample spaces and set theory
#     4. Axioms of probability
#     5. Probability of equal likelihood
#     6. Conditional probabilities
#     7. Bayes' formula and independent events
#     8. Discrete random variables
#     9. Expectations of discrete random variables
#     10. Variance
#     11. Binomial random variables, repeated trials and the so-called Modern Portfolio Theory
#     12. Poisson random variables
#     13. Poisson processes
#     14. More discrete random variables
#     15. Continuous random variables
#     16. Uniform random variables
#     17. Normal random variables
#     18. Exponential random variables
#     19. More continuous random variables
#     20. Joint distribution functions
#     21. Sums of independent random variables
#     22. Expectation of sums
#     23. Covariance
#     24. Conditional expectation
#     25. Moment generating distributions
#     26. Weak law of large numbers
#     27. Central limit theorem
#     28. Strong law of large numbers and Jensen's inequality
#     29. Markov chains
#     30. Entropy
#     31. Martingales and the Optional Stopping Time Theorem
#     32. Risk Neutral Probability and Black-Scholes
