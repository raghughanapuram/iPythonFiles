# %% [markdown]
# **Digital Signal Processing**: (Prandoni, Vetterli) [Playlist](https://www.youtube.com/playlist?list=PL80_E134xi2DJwkXlVC3TAFLnlFdnHAJX) [Syllabus - Coursera](https://www.coursera.org/course/dsp)
#
# 1. Introduction
# 2. Discrete-time (DT) signals
# 3. Euclid and Hilbert
# 4. Fourier Analysis
# 5. Linear Filters
# 6. Interpolation and Sampling
# 7. Stochastic Signal Processing
# 8. Image Processing
# 9. Digitial Communication Systems
#
# - Text:
#     - Vetterli, et al., *Foundations of Signal Processing*
#     - Kovacevic, et al., *Fourier and Wavelet Signal Processing*
#
# ** Mathematical Foundations of Signal Processing**: [Course Page](http://lcav.epfl.ch/cms/site/lcav/lang/en/SP_Foundations)
#
# 1. From Euclid to Hilbert
#     - Vector spaces
#     - Hilbert spaces
#     - Approximations
#     - Projections and decompositions
#     - Bases and frames
# 2. Sequences and Discrete-Time Systems
#     - Sequences
#     - Systems
#     - Discrete-time Fourier transform
#     - z-transform
#     - DFT
#     - Multirate sequences and systems
#     - Stochastic processes and systems
# 3. Functions and Continuous-Time Systems
#     - Functions
#     - Systems
#     - Fourier transform
#     - Fourier series
#     - Continuous stochastic processes and systems
# 4. Sampling and Interpolation
#     - with finite-dimensional vectors
#     - with sequences
#     - with functions
#     - with periodic functions
#     - with stochastic processes
# 5. Approximation and Compression
#     - by polynomials
#     - by splines
#     - by series
# 6. Localization and uncertainty
#     - for functions
#     - for sequences
#     - for bases
#     - Local Fourier and wavelet bases
#     - Time, frequency and resolution in the real world
# 7. Compressed Sensing
#     - sparse signals
#     - compressed acquisition
#     - reconstruction algorithms
#     - Applications

# %% [markdown]
# **Digital image processing** [Coursera Page](https://www.coursera.org/course/images?from_restricted_preview=1&course_id=462&r=https%3A%2F%2Fclass.coursera.org%2Fimages-2012-001%2Fclass)
#
# 1. What is image and video processing?
# 2. Images are everywhere
# 3. The human visual system
# 4. Image formation - Sampling Quantization
# 5. The why and how of compression
# 6. Huffman coding
# 7. JPEG 8x8 blocks
# 8. The Discrete Cosine Transform (DCT)
# 9. Quantization
# 10. JPEG_LS and MPEG
# 11. Bonus Run-length compression
# 12. Introduction to image enhancement
# 13. Enhancement histogram modification
# 14. Histogram equalization
# 15. Histogram matching
# 16. Introduction to local neighborhood operations
# 17. Mathematical properties of averaging
# 18. Non-Local means
# 19. Median filter
# 20. Gradients of scalar and vector images
# 21. What is image restoration
# 22. Noise types
# 23. Estimating noise
# 24. Degradation function
# 25. Wiener filtering
# 26. Introduction to segmentation
# 27. On Edges and Regions
# 28. Hough transform
# 29. Interactive Image Segmentation
# 30. Introduction to PDEs in Image and Video Processing
# 31. Planar Differential Geometry
# 32. Surface Differential Geometry
# 33. Curve Evolution
# 34. Anisotropic Diffusion
# 35. Sparse modeling and Dictionary learning
#
# - Texts:
#     - Gonzalez & Woods, *Digital Image Processing*
#     - Elad, "Sparse and Redundant Representations: From Theory to Applications in Signal and Image Processing"
#     - Shapiro, "Geometric Partial Differential Equations in Image Analysis"
#     - Bronstein, et al., "Numerical Geometry of Non-Rigid Shapes"
#     - Rosenfeld, *Digital Picture Processing*

# %% [markdown]
# **Advanced Topics in Digital Signal Processing** [Justin Romberg](http://users.ece.gatech.edu/justin/Justin_Romberg.html) [Course Page](http://users.ece.gatech.edu/~justin/ECE-6250-Fall-2013/)
#
# 1. Signal representations in vector space
#     - Introduction to discretizing signals using a basis: the Shannon-Nyquist sampling theorem
#     - Linear vector spaces, linear independence, and basis expansions
#     - Norms and inner products
#     - Orthobases and the reproducing formula
#     - Parseval's theorem and the general discretization principle
#     - Import orthobases: Fourier, discrete cosine, lapped orthogonal, splines, wavelets
#     - Signal approximation in an inner product space
#     - Gram-Schmidt and the QR decomposition
# 2. Linear inverse problems
#     - Introduction to linear invers problems
#     - the singular value decompostion (SVD)
#     - Least-squares solutions to inverse problems and the pseudo-inverse
#     - Stable inversion and regularization
#     - Weighted least-squares and linear estimation
#     - Least-squares with linear constraints
# 3. Computing the solutions to least-squares problems
#     - Cholesky and LU decompositions
#     - Structured matrices: Toeplitz, diagonal+low rank, banded systems
#     - Large-scale systems: deepest descent
#     - Large-scale systems: The conjugate gradient method
# 4. Low-rank updates for streaming solutions to least-squares problems
#     - Recursive least-squares
#     - The Kalman filter
# 5. Matrix approximation using least-squares
#     - Low-rank approximation of matrices using the SVD
#     - Total least-squares
#     - Principal component analysis
# 6. Beyond least-squares (topics as time permits)
#     - Gradient descent and Newton's method for unconstrained convex optimization
#     - Contrained optimization
#     - $l_1$ approximation and regularization
#     - Independent component analysis
#
# - Texts:
#     - Moon & Stirling, *Mathematical Methods an Algorithms for Signal Processing*
#     - Strang, *Linear Algebra and its Applications*
#     - Strang, *Introduction to Applied Mathematics*
#     - Horn and Johnson, *Matrix Analysis*
#     - Laub, *Matrix Analysis for Scientists and Engineers*
#     - Young, *An Introduction to Hilbert Space*
#     - Scharf, *Statistical Signal Processing*

# %% [markdown]
# **Signals and Systems** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-003-signals-and-systems-fall-2011/)
#
# 1. Signals and Systems
# 2. Discrete-Time (DT) Systems
# 3. Feedback, Poles, and Fundamental Modes
# 4. Continuous-Time (CT) Systems
# 5. Z Transform
# 6. Laplace Transform
# 7. Discrete Approximation of Continuous-Time Systems
# 8. Convolution
# 9. Frequency Response
# 10. Feedback and Control
# 11. Continuous-Time (CT) Frequency Response and Bode Plot
# 12. Feedback and Control
# 13. Feedback and Control II
# 14. Fourier representations
# 15. Fourier series
# 16. Fourier transform
# 17. Discrete-Time (DT) Frequency representations
# 18. Discrete-Time (DT) Fourier representations
# 19. Relations Among Fourier representationsn
# 20. Applications of Fourier transforms
# 21. Sampling
# 22. Sampling and Quantization
# 23. Modulation I
# 24. Modulation II
# 25. Audio CD

# %% [markdown]
# **Digital Communications Systems** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-02-introduction-to-eecs-ii-digital-communication-systems-fall-2012/calendar/)
#
# 1. Bits
#     - Introduction and objectives for communication systems, information and entropy, Huffman coding
#     - Source coding: Huffman codes and LZW
#     - Errors and binary symmetric channels, error correction introduction
#     - Error correction (channel coding), Hamming distance, parity bits
#     - Rectangular parity codes, Hamming codes, linear block codes, interleaving
#     - Convolutional codes
#     - Viterbi decoding of convolutional code
# 2. Signals
#     - Gaussian noise, SNR and BER, dB scale
#     - Transmitting on a physical channel: the bits-signal boundary, digital signaling, modulation and demodulation
#     - Linear, time-invariant (LTI) channel models in continuous time (CT) and discrete time (DT), step response, unit sample (impulse) response, convolution, causality
#     - Intersymbol interference (ISI), PyAudio channel demo, understanding LTI systems through their frequency response
#     - Filters and composition, deconvolution as (noise-sensitive) inverse filtering
#     - Fourier transfromation to display the spectrum of a periodic signal (discrete-time Fourier series)
#     - Discrete-time Fourier series, spectrum of non-periodic signals (discrete-time Fourier transforms), spectral character of noise
#     - modulation on a sinusoidal carrier, demodulation (time-domain and frequency-domain interpretations), sharing spectrum using multiple carriers
#     - Signals in time and frequency, LTI channels, filtering, and modulation/demodulation: how these come together in modern design
# 3. Packets
#     - Multi-hop networks, packet switching, queues, sources of delay
#     - Sharing a channal: MAC protocols (TDMA, Aloha)
#     - Network layer: routing protocols (without failures)
#     - Network layer: routing protocols (handling failures), comparing distance vector and link-state protocols
#     - Transport protocols: reliable data delivery
#     - Transport protocols: improving throughput with sliding windows
#     - From the telegraph to the Internet
#
# - Text: [*Bits, Signals and Packets: An Introduction to Digital Communications and Networks*](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-02-introduction-to-eecs-ii-digital-communication-systems-fall-2012/readings/)

# %% [markdown]
# **Principles of Digital Communication** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-450-principles-of-digital-communication-i-fall-2009/)
#
# 1. Introduction: A layered view of digital communication
# 2. Discrete source encoding
# 3. Memory-less sources, prefix free codes, and entropy
# 4. Entropy and asymptotic equipartition property
# 5. Markov sources and Lempel-Ziv universal codes
# 6. Quantization, high-rate quantizers, and waveform encoding
# 7. Fourier series and Fourier transforms
# 8. Measure
# 9. Discrete-time Fourier transforms and sampling theorem
# 10. Degrees of freedom, orthonormal expansions, and aliasing
# 11. Signal space, projection theorem, and modulation
# 12. Nyquist theory, pulse amplitude modulation (PAM), quadrature amplitude modulation (QAM), and frequency translation
# 13. Random processes
# 14. Jointly Gaussian random vectors and processes and white Gaussian noise (WGN)
# 15. Linear functionals and filtering of random processes
# 16. Introduction to detection
# 17. Detection for random vectors and processes
# 18. Theorem of irrelevance, M-ary detection, and coding
# 19. Review of theorem of irrelevance and introduction to wireless communication
# 20. Introduction to wireless communication
# 21. Discrete-time baseband models for wireless channels
# 22. Doppler spread, time spread, coherence time, and coherence frequency
# 23. Detection for flat Rayleigh fading and incoherent channels, ad rake receivers
#
# Text: Gallagher, *Principles of Digitial Communication*
#
# **Principles of Digital Communication II** [MIT OpenCourseware](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-451-principles-of-digital-communication-ii-spring-2005/)
#
# 1. Sampling Theorem and Orthonormal PAM/QAM
# 2. Performance of Small Signal Constellations
# 3. Hard-decision and Soft-decision Decoding
# 4. Introduction to Binary Block Codes
# 5. Introduction to Finite Fields
# 6. Reed-Solomon Codes
# 7. Introduction to Convolutional Codes
# 8. Trellis Representations of Binary Linear Block Codes
# 9. Codes on Graphs
# 10. The Sum-Product Algorithm
# 11. Turbo, LDPC, and RA Codes
# 12. Lattice and Trellis codes
# 13. Linear Gaussian Channels

# %% [markdown]
# - **Signal and Image Processing**
#     - Statistical signal processing[rm1]
#     - Human audiovisual system
#     - Continuous Fourier analysis, Fourier transform (FT). Amplitude and power spectrums for periodic and non-periodic signals. Power spectral analysis and cosine transform (CT)
#     - Convolution, correlation and Fourier Transform
#     - Analogue filter design
#     - Sampling and aliasing
#     - Discrete signal analysis and z transforms
#     - Discrete FT (Fast FT – FFT; Discrete CT - DCT)
#     - Digital filters and their design (FIR and IIR)
#         - Random signals
#         - Adaptive filtering
#         - 2D FTs (difference between 2D and 1D, 2D DCT)
#         - Mpeg (music) and jpeg (image) coding
#         - Point and group image operators (and convolution)
#         - Edge detection in images
#         - Image shape extraction (Template matching, HT and correlation))
#         - Shape extraction by evolution
#         - Image filtering
#         - Image restoration
#
#     - Texts:
#         - Discrete-Time Signal Processing , Oppenheim and Schafer, 2013
#         - Continuous and Discrete Time Signals and Systems, Mandal and Asif, 2007
#         - Signals and Systems, Haykin, 2003
#         - Schaum's Outline of Signals and Systems, 3rd Edition (Schaum's Outline Series), 2013

# %% [markdown]
# - **The Fourier Transform and its Applications** [page](http://see.stanford.edu/see/lecturelist.aspx?coll=84d174c2-d74f-493d-92ae-c3f45c0ee091) [Videos](https://www.youtube.com/view_play_list?p=B24BC7956EE040CD)
#     1. Introductions; Periodicity and Fourier series
#     2. Fourier series and orthogonality
#     3. Fourier series cont'd
#     4. Applications of Fourier series
#     5. Meet the Fourier transform
#     6. Fourier transform properties and examples
#     7. Convolution
#     8. Convolution, filters, and differential equations
#     9. Convolution and the Cenral Limit Theorem
#     10. Distributions
#     11. Distributions and the Fourier transform
#     12. Operations and distributions
#     13. Distributions finis, Deltas and more
#     14. Deltas, diffraction and III
#     15. Sampling and interpolation
#     16. Sampling and Aliasing
#     17. The discrete Fourier transform
#     18. Applications and properties
#     19. Applications and properties of the DFT
#     20. The FFT algorithm
#     21. Linear systems
#     22. Linear time-invariant systems
#     23. Digital filters
#     24. Higher dimensional Fourier transforms
#     25. Cystallography; Intro to medical imaging
#     26. The Radon transform & medical imaging
