# %% [markdown]
# **Artificial and Robotic Vision**: [Course Playlist](https://www.youtube.com/playlist?list=PL513vUSBNcuErCRoUpP_OnRo7TRWzkgqm) [Home Page](https://engineering.purdue.edu/elab/)
#
# 1. Introduction
# 2. Motivational lecture. Why?
# 3. Introduction to Torch 7 and Lua
# 4. Introduction to neural networks
# 5. Convolutional Neural networks
# 6. Convolutional Neural Networks details
# 7. Demonstration of the Face Detector
# 8. Code of the Face detector demo in Torch7
# 9. code for training the face detector demo in Torch7
# 10. Supervised Learning
# 11. Unsupervised Learning
# 12. Clusteing Learning
# 13. More details on deep networks
# 14. Vision Systems with deep networks
# 15. Online learner

# %% [markdown]
# ** RGB-D Workshop on 3D Perception in Robotics ** [Site](http://ias.in.tum.de/events/rgbd2011)
#
# 1. (Newcombe) Live Dense Reconstruction with a Single Moving Camera
# 2. (Paul, Newman) FAB-MAP 3D: Topological Mapping with Spatial and Visual Appearance
# 3. (Pomerlau, et al) A test bench to improve registration using RGB-D sensors
# 4. (Engelhard et al.) Real-time 3D visual SLAM with a hand-held RGB-D camera
# 5. (Bohg, et al.) Acting and Interacting in the Real World
# 6. (Madry, et al.) 2D/3D Object Categorization for Task Based Grasping
# 7. (Swadzba, et al.) The Articulated Scene Model: Model-less Priors for Robot Object Learning
# 8. (Lange, et al.) Autonomous Corridor Flight of a UAV Using an RGB-D Camera
# 9. (Cubber, et al.) Outdoor terrain transversability analysis for robot navigation using a time-of-flight camera
# 10. (Strachan, Siebert) 2.5D Local Feature Matching System
# 11. (Kirchheim, et al.) Evaluation of 3D Model Accuracy for Automated Unloading of Containers
# 12. (Lai) RGB-D Object Dataset and RGB-D Object Recognition, Pose detection and pose estimation
# 13. (Tombari) RGB_D object recognition and localization with clutter and occlusions
# 14. (Marton et al.) Efficient surface and feature estimation in RGBD
#
# **Introduction to Machine Vision** [Playlist](https://www.youtube.com/playlist?list=PL1pxneANaikCO1-Z0XTaljLR3SE8tgRXY)
#
# 1. Introduction to robot vision
# 2. Image processing
# 3. blob features
# 4. Color
# 5. The source of color
# 6. blob features and mathematical morphology
# 7. image formation
# 8. image geometry and planar homography

# %% [markdown]
# **Fundamentals of Computer Vision**: [Mubarak Shah](http://crcv.ucf.edu/people/faculty/shah.php) [Playlist](https://www.youtube.com/playlist?list=PLmyoWnoyCKo8epWKGHAm4m_SyzoYhslk5)
#
# 1. Introducing Computer Vision
# 2. Filtering
# 3. Edge Detection
# 4. Interest Point Detection
# 5. Scale-Invariant Feature Transform (SIFT)
# 6. Optical Flow
# 7. Pyramids
# 8. Motion Models
# 9. Global Motion
# 10. Lucas-Kanade Tracker (KLT)
# 11. Mean Shift
# 12. Camera Model
# 13. Fundamental Matrix
# 14. Face Recognition
# 15. Structure from Motion
# 16. Stereo
# 17. Bag-of-Features (Bag-of-Words)
# 18. Hough Transform
# 19. Matlab Tutorial Video
# 20. Histograms of Oriented Gradients
#
# ** Advanced Computer Vision**: (same as above)
#
# [Course Page](http://www.cs.ucf.edu/courses/cap6412/spr2014/)
#
# **Computer Vision Systems**: (same as above)
#
# [Course Page](http://www.vision.eecs.ucf.edu/courses/cap6411/fall2010/)
#
# 1. Camera model and Pose Estimation
# 2. Optical Flow and Pyramids
# 3. Global Flow and Levenberg Marquardt
# 4. Motion Layers Extraction
# 5. Face Recognition
# 6. Kinematic Features
#
# - Text: Szeliski, *Computer Vision: Algorithms and Applications*

# %% [markdown]
# ** Visual Perception and its Neural Substrates** [Link](http://redwood.berkeley.edu/wiki/VS298:_Visual_Perception_and_its_Neural_Substrates) Karl Zipser
#
# 1. The V1 classical receptive field:
#     - Schiller, P. H., Finlay, B. L., & Volman, S. F. (1976). [Quantitative studies of single-cell properties in monkey striate cortex. I. Spatiotemporal organization of receptive fields](https://www.dropbox.com/s/7t284hq71tpywor/1976%20Schiller%20Finlay%20Volman%20I.pdf?dl=0). Journal of neurophysiology, 39(6), 1288-1319. pdf
#     - Schiller, P. H., Finlay, B. L., & Volman, S. F. (1976). [Quantitative studies of single-cell properties in monkey striate cortex. II. Orientation specificity and ocular dominance](https://www.dropbox.com/s/ooyroll4386nn9e/1976%20Schiller%20Finlay%20Volman%20II.pdf?dl=0). Journal of neurophysiology, 39(6), 1320-1333. pdf
#     - Schiller, P. H., Finlay, B. L., & Volman, S. F. (1976). [Quantitative studies of single-cell properties in monkey striate cortex. III. Spatial frequency](https://www.dropbox.com/s/txywhbenit92bak/1976%20Schiller%20Finlay%20Volman%20III.pdf?dl=0). Journal of Neurophysiology, 39(6), 1334-1351. pdf
#     - Finlay, B. L., Schiller, P. H., & Volman, S. F. (1976). [Quantitative studies of single-cell properties in monkey striate cortex. IV. Corticotectal cells](https://www.dropbox.com/s/f00ow3io6l60hvg/1976%20Schiller%20Finlay%20Volman%20IV.pdf?dl=0). Journal of Neurophysiology, 39(6), 1352-1361. pdf
#     - Schiller, P. H., Finlay, B. L., & Volman, S. F. (1976). [Quantitative studies of single-cell properties in monkey striate cortex. V. Multivariate statistical analyses and models](https://www.dropbox.com/s/0t3yx4yt133i64o/1976%20Schiller%20Finlay%20Volman%20V.pdf?dl=0). Journal of Neurophysiology, 39(6), 1362-1374. pdf
# 2. Fine structure for parallel processing in visual cortex:
#     - Nassi, J. J., & Callaway, E. M. (2009). [Parallel processing strategies of the primate visual system](https://www.dropbox.com/s/8c1f38zysyvxpmy/2009%20Parallel%20processing%20strategies%20of%20the%20primate%20visual%20system.pdf?dl=0). Nature Reviews Neuroscience, 10(5), 360-372 pdf
#     - Horton, J. C., & Adams, D. L. (2005). [The cortical column: a structure without a function](https://www.dropbox.com/s/6ktyz9zp4v8vf8b/2005%20The%20cortical%20column.pdf?dl=0). Philosophical Transactions of the Royal Society B: Biological Sciences, 360(1456), 837-862. pdf
#     - Daniel L. Adams, D.L & Horton, J.C. (2009) [Ocular Dominance Columns: Enigmas and Challenges](https://www.dropbox.com/s/bcnvpn1fyn7i17q/2009%20Ocular%20Dominance%20Columns%20Enigmas%20and%20Challenges.pdf?dl=0). Neuroscientist 15: 62 pdf
# 3. The stable world problem:
#     - Dyson, Freeman. [The Case for Blunders](http://www.nybooks.com/articles/archives/2014/mar/06/darwin-einstein-case-for-blunders). The New York Review of Books, 6 March 2014. pdf
#     - [Machine-Learning Maestro Michael Jordan on the Delusions of Big Data and Other Huge Engineering Efforts](http://spectrum.ieee.org/robotics/artificial-intelligence/machinelearning-maestro-michael-jordan-on-the-delusions-of-big-data-and-other-huge-engineering-efforts), 20 Oct 2014, Lee Gomes, IEEE Specturm link
#     - Yann LeCunn responds to Mike Jordan's Spectrum interview [link](https://www.facebook.com/yann.lecun/posts/10152348155137143)
#     - Kravitz, D. J., Saleem, K. S., Baker, C. I., Ungerleider, L. G., & Mishkin, M. (2013). [The ventral visual pathway: an expanded neural framework for the processing of object quality](http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3532569/pdf/nihms419686.pdf). Trends in cognitive sciences, 17(1), 26-49. pdf
#     - Vinyals, O. et al. [Show and Tell: A Neural Image Caption Generator](http://arxiv.org/pdf/1411.4555v1.pdf). 2014 arXiv.1411.4555v1 pdf
#     - Koch, C., & Tononi, G. (2011). [A test for consciousness](https://www.dropbox.com/s/h2bo3swrjr1g1l1/A_Test_for_Consciousness.pdf?dl=0). Scientific American, 304(6), 44-47. pdf

# %% [markdown]
# - ** Unsolved Problems in Vision** [Course Materials](http://redwood.berkeley.edu/wiki/VS298:_Unsolved_Problems_in_Vision)
#     1. Introduction
#         - [*Gibson's unsolved problems*](http://www.trincoll.edu/depts/ecopsyc/perils/folder2/issues.html)
#     2. Methodology in vision science
#         - Klein, [*Double-judgment psychophysics: problems and solutions*](http://cornea.berkeley.edu/pubs/34.pdf)
#         - Klein, [*Measuring, estimating, and understanding the psychometric function*](http://cornea.berkeley.edu/pubs/01-11_PERCEPTION_AND_PSYCHOPHYSICS-Measuring_estimating_and_understanding_the_psychometric_function.pdf)
#         - Psychophysics
#         - Marcus background discussion
#             - Beyond Hubel and Wiesel [video](https://vimeo.com/87683403)
#             - Selected Chapters from Algebraic Mind [introduction](http://www.psych.nyu.edu/gary/TAM/intro_section.html#introduction) and [rules and variables](http://www.psych.nyu.edu/gary/TAM/rules.html#rules_and_variables)
#             - New Yorker piece on deep nets [site](http://www.newyorker.com/news/news-desk/is-deep-learning-a-revolution-in-artificial-intelligence)
#     3. [Grant Formats](https://www.dropbox.com/s/2onrsi6n6338bjb/4Dec2014%20Grant%20PDF.pdf?dl=0)
#     4. Gary Marcus: *Computational Diversity and the mesoscale organization of the neocortex* [VIDEO](https://archive.org/details/Redwood_Center_2014_09_19_Gary_Marcus)
#     5. Feldmann background discussion
#         - Feldman (2008), *From molecule to metaphor: A neural theory of language.*
#         - Feldman (2013), [*The neural binding problem*](ftp://ftp.icsi.berkeley.edu/pub/feldman/binding.cody.pdf)
#         - Feldman & Narayanan (2014), [*Affordances, Actionability, and Simulation.*](ftp://ftp.icsi.berkeley.edu/pub/feldman/affordances.jf.pdf)
#         - Feldman, (2009), [*Ecological expected utility and the mythical neural code*](ftp://ftp.icsi.berkeley.edu/pub/feldman/affordances.jf.pdf)
#         - Sommer, 2014, [*Neural oscillatons and synchrony as mechanisms for coding, communication and computation in the visual system*]
#     6. Feldman: *The neural binding problem(s) and related mysteries* [VIDEO](https://archive.org/details/uc_berkeley_vs298_2014_10_01_Jerry_Feldman)
#     7. Feldman/Malik discussion
#         - Girshick, et al., 2014, [*Rich feature hierarchies for accurate object detectino and semantic segmentation*](http://www.cs.berkeley.edu/~rbg/papers/r-cnn-cvpr.pdf)
#         - Abelaez et al. 2014, [*Multiscale Combinatorial Grouping*](http://www.cs.berkeley.edu/~rbg/papers/r-cnn-cvpr.pdf)
#         - Hariharan, et al. 2014, [*Simultaneous Detection and Segmentation*](http://www.cs.berkeley.edu/~bharath2/pubs/pdfs/BharathECCV2014.pdf)
#         - Gupta, et al. 2014, [*Learning Rich Features from RGB-D Images for Object Detection and Segmentation*](http://www.cs.berkeley.edu/~sgupta/pdf/rcnn-depth.pdfv)
#     8. Jitendra Malik: [*The Three R's of Computer Vision: Recongition, Reconstruction, and reorganization*](https://archive.org/details/ucb_vs298_2014_10_14_Jitendra_Malik)
#     9. Harold Bedell: [*Contour interaction: as far from the muddling crowd*](https://archive.org/details/ucb_vs298_2014_10_20_Harold_Bedell)
#         - Siderov, Waugh, Bedell, 2013, [*Foveal contour interaction for low contrast acuity target*](https://archive.org/details/ucb_vs298_2014_10_20_Harold_Bedell)
#         - Coates, Levi, 2013, [*Countour interaction in foveal vision: A response to Siderov et al*](http://www.sciencedirect.com/science/article/pii/S0042698913002587)
#         - Siderov, J., Waugh, S. J., & Bedell, H. E. (2014). [*Foveal contour interaction on the edge: Response to ‘Letter-to-the-Editor’*](https://www.dropbox.com/s/2so6z5yxrsgs5iy/Siderov%20etal%20CI%20on%20Edge%20Reply%20VR_14.pdf?dl=0)
#     10. Nakayama and Shimojo background discussion
#         - Nakayama, K. (1999). [Mid-level vision](http://visionlab.harvard.edu/members/ken/Papers/100mitencyclopedia99.pdf). In R. A. Wilson & F. C. Keil (Eds.), The MIT encylopedia of the cognitive sciences Cambridge: MIT Press pdf
#         - Nakayama, K. (2010) "[Vision going social](http://visionlab.harvard.edu/members/ken/Papers/160NakayamaVisionGoingSocial.pdf)." The science of social vision. Adams, R.B. Jr., Ambady, N., Nakayama, K. & Shimojo, S. (Eds) Oxford University Press pdf
#         - Nakayama, K. and Martini, P. (2011) [Situating Visual Search](http://visionlab.harvard.edu/members/ken/Papers/166NakayamaMartiniSVS2011.pdf). Vision Research, 51, 1526-1537. pdf
#         - (All Nakayama pubs available [here](http://visionlab.harvard.edu/members/ken/nakayamapub.htm)
#         - Shimojo, S. (2014). [Postdiction: its implications on visual awareness, hindsight, and sense of agency](http://journal.frontiersin.org/article/10.3389/fpsyg.2014.00196/full). Frontiers in psychology, 5. pdf
#     11. Nakayama: *the scientist's choice: solving. explaining, discovering*
#     - Roth & Black: Fields of experts, [paper](https://www.dropbox.com/s/w6lhf9li8tsexnm/roth-black05.pdf)
#     - Hinton: Practical guide to training RBMs [paper](https://www.dropbox.com/s/8kxbkrmay5h9abf/hinton-rbm-guideTR.pdf)
#     - Teh et al: Energy-based models for sparse overcomplete representation, [paper](https://www.dropbox.com/s/ph17gczh2l1e9qa/teh-etal-jmlr03.pdf)
#     - Zhu, Wu & Mumford: FRAME (Filters, random fields, and maximum entropy), [paper](https://www.dropbox.com/s/fxcc1gx1vfz1mwo/zhu-wu-mumford-FRAME.pdf)
# 8. Learning invariances through "slow feature analysis"
#     - Foldiak/Wiskott: slow feature analysis, [paper1](https://www.dropbox.com/s/ce4ngfyop94whhj/foldiak91.pdf), [paper2](https://www.dropbox.com/s/v3dgj50jp6sc26p/wiskott-sejnowski02.pdf)
#     - Hyvarinen: 'Bubbles' [paper](https://www.dropbox.com/s/1u7cmflubvt0zfy/hyvarinen-bubbles03.pdf)
#     - **Berkes et al.: factorizing 'what' and 'where' from video**, [paper](https://www.dropbox.com/s/us4fmd6vphacc4x/berkes-etal09.pdf)
# 9. Manifold and Lie group models
#     - Carlsson et al.: Klein bottle model of natural images, [paper](https://www.dropbox.com/s/egaeuqpr7spuaaq/carlsson-etal07.pdf)
#     - Culpepper & Olshausen: Learning manifold transport operators, [paper](https://www.dropbox.com/s/1yqnpg7mfodfd8y/culpepper-olshausen09.pdf)
#     - Roweis & Saul: Local Linear Embedding, [paper](https://www.dropbox.com/s/xbslejj4jl7723q/roweis-saul00.pdf)
# 10. Hierarchical models
#     - Karklin & Lewicki (2003): density components, [paper](https://www.dropbox.com/s/urjwi875vhtmyww/karklin-lewicki03.pdf)
#     - Shan & Cottrell: stacked ICA, [paper](https://www.dropbox.com/s/urjwi875vhtmyww/karklin-lewicki03.pdf)
#     - Cadieu & Olshausen (2012): learning intermediate representations of form and motion, [paper](http://redwood.berkeley.edu/cadieu/drafts/cadieu&olshausen_NC_insub_071111.pdf) [Video Presentation](https://www.youtube.com/watch?v=4UWMt7zyH4k)
# 11. Deep network models
#     - Hinton & Salakhudinov (2006): stacked RBMs, [paper](https://www.dropbox.com/s/bjtfiiu44skwuzl/hinton-salakutdinov06.pdf)
#     - Le et al. (2011): Unsupervised learning (Google brain, 'cat' neurons), [paper](https://www.dropbox.com/s/ydd91bhv0qj69rr/le-etal12.pdf)
#     - Krishevsky et al. (2012): Supervised learning, ImageNet 1000 [paper](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks.pdf) [NIPS 2012](http://papers.nips.cc/book/advances-in-neural-information-processing-systems-25-2012)
#      - Mnih, et al. 2014, Playing Atari with Deep Reinforcement Learning [paper](http://www0.cs.ucl.ac.uk/staff/D.Silver/web/Publications_files/dqn.pdf)
# 12. Special topics
#     - Fergus (2013): visualizing what deep nets learn (Visualizing CNNs) [paper](http://arxiv.org/abs/1311.2901)
#     - Schmidhuber: deep nets ([paper](http://arxiv.org/pdf/1312.5548.pdf)), focusing on LOCOCODE ([paper](http://citeseerx.ist.psu.edu/viewdoc/summary?doi=10.1.1.51.1412))
#     - Formation of Early Retinal Circuits in the Inner Plexiform Layer by Kevin J. Ford and Marla Feller
#     - Development of cell types and synaptic connections in the retina by Josh Morgan and Rachel Wong
#     - Development of Retinal Ganglion Cell Dendritic Structure and Synaptic Connections by Ning Tian
# - Part VII: Color Vision
#     - Color Vision by Peter Gouras
# - Part VIII: Psychophysics of Vision
#     - Psychophysics of Vision by Michael Kalloniatis and Charles Luu
#     - Visual Acuity by Michael Kalloniatis and Charles Luu
#     - Temporal Resolution by Michael Kalloniatis and Charles Luu
#     - Light and Dark Adaptation by Michael Kalloniatis and Charles Luu
#     - Color Perception by Michael Kalloniatis and Charles Luu
#     - Space Perception by Michael Kalloniatis and Charles Luu
#     - Perception of Depth by Michael Kalloniatis and Charles Luu
# - Part IX: Brain Visual Areas
#     - The Primary Visual Cortex by Matthew Schmolesky
# - Part X: Repair and Regeneration in the visual sytem
#     - Regeneration in the Goldfish Visual System by Sam Nona
#     - Regeneration in the visual system of adult mammals by Yves Sauve and Frederic Gaillard
#     - Fetal tissue allografts in the central visual system of rodents by Frederic Gaillard and Yves Sauve
# - Part XI: Electrophysiology
#     - Visually Evoked Potentials by Donnell J. Creel
#     - The Electroretinogram: ERG by Ido Perlman
#     - The Electroretinogram and Electro-oculogram: Clinical Applications by Donnell J. Creel
#     - Visual And Auditory Anomalies Associated With Albinism
# - Part XII: Cell biology of retinal degenerations
#     - Cellular Remodeling in Mammalian Retina Induced by Retinal Detachment by Steve Fisher
#     - Age-Related Macular Degeneration (AMD) by Gregory S. Hageman
# - Part XIII: Facts and Figures concerning the human retina
# - Part XIV: Evolution of Phototransduction, Vertebrate Photoreceptors and Retina by Trevor Lamb

# %% [markdown]
# - **Computer Vision**
#     - The human eye-brain system as a model for computer vision
#     - Image formation: sampling theorem, Fourier transform and Fourier analysis
#     - Image models
#     - Basic image processing: Sampling and quantisation, Brightness and colour, Histogram operations, Filters and convolution, Frequency domain processing
#     - Edge detection
#     - Boundary and line extraction
#     - Building machines that see: constraints, robustness, invariance and repeatability
#     - Fundamentals of machine-learning: classification and clustering
#     - Understanding covariance, eigendecomposition and PCA
#     - Feature extraction
#     - Interest point detection
#     - Segmentation
#     - 2-D Shape representation
#     - Local features
#     - Image matching
#     - Large-scale image search and feature indexing
#     - Understanding image data and performing classification and recognition
#     - 3D vision systems
#     - Recovering depth from multiple views
#     - Practical examples, including: biometric systems (recognising people), industrial computer vision, etc
#
#     - Text:
#         - Nixon, M.S. and Aguado, A.S. Feature Extraction & Image Processing, 3rd ed., Academic Press, 2012.
#         - Sonka, Hlavac & Boyle, Image Processing, Analysis and Machine Vision, 3rd ed., PWS Publishing, 2008.
#         - Gonzalez et al., Digital Image Processing, 3rd ed., Pearson, 2008.
#         - Stockman and Shapiro, Computer Vision, Prentice Hall, 2001.

# %% [markdown]
# - **Advanced Computer Vision**
#     - Feature Extraction
#         - Further techniques in parametric and non-parametric feature extraction including advance Hough transform techniques and active contour models.
#     - Feature Description
#         - How to describe extracted features for purposes of further analysis and in feature recognition.
#     - Image Interpretation
#         - Syntactic and symbolic image interpretation and analysis.
#     - Image Restoration
#         - Beyond the Weiner filter. Least mean squares and extensions and maximum entropy restoration.
#     - 3D Imaging
#         - Calibration, epipolar constraint, coordinate systems. Active and passive ranging systems.
#     - Morphology
#         - Binary image processing and image geometry
#     - Texts:
#         - Nixon, M S and Aguado, A S, Feature Extraction and Image Processing in Computer Vision Butterworth Heinmann (Newnes) 3rd Edition 2012, Book website http://www.ecs.soton.ac.uk/~msn/book
#         - Simon Prince, Computer Vision: Models, Learning, and Inference, Cambridge University Press 2011
#         - Roy Davies, Computer anmd Machine Vision: Theory, Algorithms, Practicalities. Academic Press 2012
#         - Learning OpenCV: Computer Vision with the OpenCV Library by Gary Bradski and Adrian Kaehler 2008
#         - Mastering OpenCV with Practical Computer Vision Project, Baggio et al 2012

# %% [markdown]
# **Arash Yazdanbakhsh Vision Courses** [Course Collection](http://cns.bu.edu/~yazdan/)
#
# - **Introduction to Computational Models of Vision**
#     1. Fundamental Problems of vision
#     2. Styles of explanation in computational vision
#     3. Survey of "information processing" approaches to vision
#     4. Representation in early vision (center-surround, DoG)
#     5. Input dynamic range and contrast gain control (noise-saturation dilemma, need to supplement retinal adaptation/bleaching with cortical background adaptation)
#     6. Introduction to integrate and fire neurons and shunting competitive networks (divisive normalization)
#         - Grossberg, 1982, "Why do cells compete?"
#     7. Stimulus contrast, contrast sensitivity,and brightness contrast
#     8. Shunting networks, contrast and constancy (ratio processing, contrast processing, "center-surround" networks with distance-dependent kernels
#     9. Early visual pathways (retinal, LGN, and V1 receptive field properties)
#     10. Oriented Receptive fields and edge processing (simple and complex cells)
#     11. Nonlinear cortical prcocessing: Short range competition (end-stopping, understood as competition among orientation-selective cells, and cross-orientation inhibition)
#         - Yazdanbakhsh, Livingstone, 2006, *End stopping in V1 is sensitive to contrast* [paper](http://www.cns.bu.edu/~yazdan/PostDoc/ArashMarge06.pdf)
#     12. Surface perception and its temporal dynamics
#         - Rossi, Paradiso, 1999, *Neural correlated of perceived brightness in the retina, lateral geniculate nucleus and striate cortex* [paper](http://www.cns.bu.edu/Profiles/Mingolla.html/cnsftp/RossiParadiso99.pdf)
#     13. Illusory contours, water-color effect, and neon color spreading
#     14. Cortical magnification factor
#         - Schwartz, 1977, *Spatial Mapping in the Primate Sensory Projection: Analytic Sturcture and Relevance to Perception* [paper](http://eslab.bu.edu/publications/articles/1977/schwartz1977spatial.pdf)
#     15. Temporal dimension of receptive fields (temporal variation of cell response)
#         - DeAngelis, Ohzawa, Freeman, 1995, *Receptive-field dynamics in the central visual pathways* [paper](http://apps.usd.edu/coglab/schieber/psyc707/pdf/TINS95.pdf)
#     16. Inter- versus intra-areal cortical connections (impact of temporal and spatial limits of connectivities within and between visual cortical areas on global visual processing)
#         - Bullier, 2001, Integrated model of visual processing [paper](http://www.allpsych.uni-giessen.de/rauisch/readings/Bullier.BrainResRev.2001.pdf)
#     17. Figure-ground segregation
#     18. Border-ownership
#         - Zhou et al, 2000, *Coding of Border Ownership in Monkey Visual Cortex*
#     19. Visual short-range motion and suggested models
#     20. Motion induced contours, figure-ground segregation, and border-ownership
#     21. Visual long-range motion and aperature problem
#     22. Frame of reference and induced motion
#     23. Visual depth, monocular cues
#     24. Visual depth, binocular cues
#         - DeAngelis, 2000, *Seeing in three dimensions: the neurophysiology of stereopsis*, [paper](http://www.bcs.rochester.edu/courses/crsinf/504/crsarc/F01/stereo.pdf)
#     25. Introduction to eye movements
#         - Martinez-Conde, Machnik, Hubel, 2004, *The role of fixational eye movements in visual perception.* [paper](http://hubel.med.harvard.edu/papers/HubelMartinez-condeetal2004NationReviewNeuroscience.pdf)
#     26. Visual Attention (inattentional blindness, attentional blink and change blindness)
#         - Fried, et al. 2001, *Modulation of Oscillatory Neuronal Synchronization by Selective Visual Attention* [paper](http://eye.snu.ac.kr/upload/class_advbiopsy/Attention_Modulates_synchronization.pdf)
# - Text: Palmer, *Vision Science: From photons to phenomenology*
#
# - **Neural and Computational Models of Vision**
#     1. Fundamental Problems in Vision
#         - Visual grouping and segregation
#         - seeing and recognizing
#         - input intergace: retina, its veins and blind spot
#         - Perceiving surface: constancy, contrast, and discounting the illuminant
#         - Boundaries and surfaces, or a different decomposition of a visual stimulus?
#         - Detectors in primate visual system: unoriented and oriented detectors
#         - The trade off between noise and saturatin in a neural signal
#         - Reflectance and ratio; shunting and mass action
#     2. Neural models and their implementation in early vision
#         - Brightness: Constancy and contrast
#         - Shift propert and Weber law
#         - Retinal physiology
#         - Back to the trade off between noise and saturation in a neural signal
#         - Distance-dependent neural processes
#         - Recurrent competitive networks
#     3. Early visual pathways + "late" neural strategies
#         - Anatomy and physiology of visual system
#         - Eyeball is not flat!
#         - Retinal structure as the image plane on a non-flat surface
#         - Function of ON and OFF channels
#         - Primary visual cortex and the concept of receptive field
#         - Beyond the primary visual cortex
#         - Callaway (1998) *Local circuits in primary visual cortex of the macaque monkey* [paper](http://cns.bu.edu/Profiles/Mingolla.html/cnsftp/pdf/Callaway1998LaminarReview.pdf)
#         - Sincich, Horton (2005), *The circuitry of V1 and V2: Integration of color, form, and motion* [paper](http://www.mbfys.ru.nl/staff/j.vangisbergen/endnote/endnotepdfs/visueel/V1_en_V2_annurev.neuro.28.061604.pdf)
#     4. Contrast sensitivities and spatial scales
#         - Structural scales, functional scales, kernels, receptive fields
#         - Peak shifts and lateral inhibition
#         - Detectors and filters, linear systems approach to vision
#         - Appropriate stimuli set for probing a visual area?
#         - Feature basis for a visual area?
#         - Brightness perception: Quantifying percepts
#         - Isomorphic and non-isomorphic approaches
#         - Hegdé, J. and Van Essen, DC. (2004). Temporal Dynamics of Shape Analysis in Macaque Visual Area V2, J. Neurophysiology, 92:3030-3042. [PDF](http://www.snl.salk.edu/~jay/PDFs/HegdeVanEssenV2TemporalDynamics.pdf).
#         - Sherbakov LO., and Yazdanbakhsh A. (2013). Multiscale sampling model for motion integration, Journal of Vision, 13(11):18, 1–14. [PDF](http://cns-classes.bu.edu/~yazdan/pdf/LenaArash13.pdf).
#         - Yazdanbakhsh, A. and M. S. Livingstone (2006). End stopping in V1 is sensitive to contrast. Nature Neuroscience 9 (5): 697-702. [PDF](http://www.cns.bu.edu/~yazdan/PostDoc/ArashMarge06.pdf).
#         - Yazdanbakhsh, A., et al., Munker-White-like illusions without T-junctions. Perception, 2002. 31(6): p. 711. PDF.
#         - Westheimer G., The Fourier theory of vision. Perception, 30(5), 531-541. [PDF](http://cns-web.bu.edu/~yazdan/pdf/westheimer2001fourier.pdf).
#     5. Brightness and lightness
#         - Brightness assimilation
#         - A few neural models for brightness perception
#         - Challenges to brightness model
#         - Achromatic Watercolor Effect (WCE)
#         - Contrast sensitivity of Wce and the polarity effect
#         - A prelude for contours and surfaces
#         - Gilchrist A, Kossyfidis C, Bonato F, Agostini T, Cataliotti J, Li X, Spehar B, Annan V, Economou E. An anchoring theory of lightness perception. Psychological Review, 1999 Oct;106(4):795-834.
#         - Li A., Tavantzis MJ., and Yazdanbakhsh A. (2009). Lightness of Munker-White illusion and Simultaneous-Contrast illusion: Establishing an ordinal lightness relation among minimum and split-frame presentations, Review of Psychology, 16(1): 3-8
#         - Cao B., Yazdanbakhsh A., Mingolla E. (2011). The effect of contrast intensity and polarity in the achromatic watercolor effect, Journal of Vision, 11(3):18, 1–8
#         - Grossberg, S. and Todorović , D. (1988). Neural dynamics of 1-D and 2-D brightness perception: A unified model of classical and recent phenomena. Perception & Psychophysics, 43, 241-277
#     6. Parallel visual pathways, boundaries and surfaces
#         - Diffusion models and time
#         - Symbolic models
#         - Edge detection?
#         - How thin is thin?
#         - Spatial and cross-orientation competition
#         - Transparency and neon color spreading
#         - Occlusion and T-junction from a border-ownership perspective
#         - Scales again: alternative approaches to diffusion
#         - Hyperacuity
#         - Craft, E., H. Schutze, et al. (2007). "A neural model of figure-ground organization." J Neurophysiol 97(6): 4310-4326 [paper](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.323.7778&rep=rep1&type=pdf)
#         - Komatsu H. (2006) The neural mechanisms of perceptual filling-in. Nat Rev Neurosci. 7(3):220-31. [paper](http://cns-classes.bu.edu/~yazdan/pdf/Komatsu-2006.pdf)
#         - Pessoa, L., Thompson, E.,  & Noe, A.  Finding out about filling-in: a guide to perceptual completion for visual science and the philosophy of perception. Behavioral and Brain Sciences, 1998 Dec;21(6):723-48. [paper](https://repository.royalholloway.ac.uk/file/40246657-18d9-76ce-051a-18a17f4650d6/8/S0140525X9800175Xa.pdf)
#         - Davey, M. P., Maddess, T., and  Srinivasan M. V. (1998). The spatiotemporal properties of the Craik-OBrien-Cornsweet effect are consistent with filling-in. Vision Research, 38(13), 2037-2046. [paper](http://cns-classes.bu.edu/~yazdan/pdf/DavMad98.pdf)
#         - Hung CP, Ramsden BM, Chen LM, Roe AW., Building surfaces from borders in Areas 17 and 18 of the cat., Vision Res. 2001;41(10-11):1389-407. [paper](http://cns.bu.edu/~yazdan/pdf/HungRamsden01.pdf)
#         - Paradiso, M. A. and Nakayama, K. (1991). Brightness perception and filling-in. Vision Research, 31, 1221-1236. [paper](http://cns-web.bu.edu/~yazdan/pdf/ParadisoNakayama1991Brightness.pdf)
#         - Bressan, P., Mingolla, E., Spillmann, L. and Watanabe, T. (1997). Neon color spreading: A review. Perception, 26(11), 1353-1366. [paper](http://cns.bu.edu/Profiles/Mingolla.html/cnsftp/pdf/Bressan-et-al-97neon.pdf)
#     7. Boundary detection, and vector representation of border-ownership
#         - How thin is thin?
#         - Spatial and cross-orientation competition
#         - Hyperacuity
#         - Neon color spreading
#         - Bipole cells versus centrally symmmetric grouping cells
#         - Border-ownership signals within the visual cortex
#         - Zhou, H., H. S. Friedman, et al. (2000). "Coding of border ownership in monkey visual cortex." J Neurosci 20(17): 6594-6611. [paper](http://cns-classes.bu.edu/~yazdan/pdf/Zhou00.pdf)
#         - Layton OW., Mingolla, E., and Yazdanbakhsh A. (2012). Dynamic coding of border-ownership in visual cortex, Journal of Vision, 12(13):8, 1–21 [paper](http://www.cns.bu.edu/~yazdan/Papers/OliverEnnioArash12.pdf)
#         - von der Heydt, R., Peterhans, E., and Baumgartner, G. (1984). Illusory contours and cortical neuron responses. Science, 224, 1260-1262.  [paper](http://cns.bu.edu/~yazdan/pdf/von_der84.pdf)
#         - Takeichi H, Shimojo S, Watanabe T. (1992). Neon flank and illusory contour: interaction between the two processes leads to color filling-in. Perception 21(3):313-24 [paper](http://cns-alumni.bu.edu/~yazdan/pdf/takeichi1992.pdf)
#         - Pasupathy, A. and Connor, C.E. (2002) Population coding of shape in area V4. Nature Neuroscience 5: 1332-1338.
#         - Francis, G., Grossberg, S., and Mingolla, E. (1994). Cortical dynamics of feature binding and reset: Control of visual persistence. Vision Research , 34 (8), 1089-1104. [paper](http://www2.psych.purdue.edu/~gfrancis/Publications/FrancisGrossbergMingolla1994.pdf)
#         - Koffka, K. (1935/1963). Principles of Gestalt psychology. New York, Harcourt, Brace, and World. Chapter 4, The environmental field, 106-176, contains many of the seminal notions of Gestalt psychology. See especially pages 148-176.
#         - Lamme VAF, Super H, Spekreijse H Feedforward, horizontal, and feedback processing in the visual cortex. CURR OPIN NEUROBIOL 8: (4) 529-535 AUG 1998.
#         - Ramsden BM, Hung CP, Roe AW. (2001). Real and illusory contour processing in area V1 of the primate: a cortical balancing act., Cereb Cortex. Jul;11(7):648-65.  This article shows the difference between V1 and V2 units in response to illusory contours. Reading the abstract, figure legends and discussion suffices. [paper](http://cercor.oxfordjournals.org/content/11/7/648.short)
#     8. The phenomena and models of motion perception
#         - What is motion? Apparent motion and real motion
#         - Long- and short-range motion: Arguments for their mechanisms
#         - Traveling Gaussian waves
#         - Short and long-range motion
#         - Motion models
#         - Kinetic edge and kinetic border-ownership
#         - Motion detection, segmentation and grouping
#         - Nakayama, K. (1985). Biological image motion processing: A review. Vision Research, 25(5), 625-660. Read 625-651.
#         - Adelson, E. H. and Bergen, J. R. (1985). Spatiotemporal energy models for the perception of motion. Journal of the Optical Society of America A, 2(2), 284-299. [paper](http://www.cns.nyu.edu/~eero/csh04/Articles/Adelson-Bergen-85.pdf)
#         - Anstis, S. (1988). Motion perception in the frontal plane. Chapter 16 of K. R. Boff, L. Kaufman, and J. P. Thomas, Eds., Handbook of perception and performance, Volume I, Sensory processes and perception, pages 16-1 to 16-27.
#         - van Santen, J. P. H. and Sperling, G. (1985). Elaborated Reichardt detectors. Journal of the Optical Society of America A, 2(2), 300-321. [paper](http://cns.bu.edu/~yazdan/pdf/vanSantenSperling1985EReichardt.pdf)
#         - Baker, et al, 2011, A database and evaluation methodology for optical flow [paper](http://128.148.32.110/people/black/Papers/FlowEvalIJCV2011.pdf)
#         - Xu, Matsushita, 2012, Motion detail preserving optical flow estimation [paper](http://lxu.me/mypapers/TPAMISI-2010-10-0825.R1.pdf)
#         - Daniilidis, Spetsakis, 2013, Understanding Noise Sensitivity in Structure from Motion [paper](http://www.cis.upenn.edu/~kostas/mypub.dir/danispets.pdf)
#         - Anandan, 1989, A Computational Framework and an Algorithm for the Measurement of Visual Motion, [paper](http://link.springer.com/article/10.1007/BF00158167#page-1)
#         - Heeger, 1988, Optical Flow Using Spatiotemporal Filters [paper](http://hopf.cns.nyu.edu/labs/heegerlab/content/publications/Heeger-IJCV1987.pdf)
#         - Burr & Thompson, 2011, Motion psychophysics: 1985-2010, [paper](http://wexler.free.fr/library/files/burr%20(2011)%20motion%20psychophysics.%201985-2010.pdf)
#         - Borst, Euler, 2011, Seeing Things in Motion: Models, circuits, and mechanisms [paper](http://www.bccn-tuebingen.de/fileadmin/user_upload/events/CVSS2012/Borst_Euler_2011.pdf)
#         - Grossberg, S. and Rudd, M. E. (1989). A neural architecture for visual motion perception: Group and element apparent motion. Neural Networks,2, 421-450. Read pages 421-433. Do not get bogged down in the description of the 5 levels of the model and on oddities such as rightward propagation of leftward motion signals. Concentrate on the traveling Gaussian wave mechanism, period.
#         - Rokers, et al 2011, Motion processing with two eyes in three dimensions [paper](http://motion.cps.utexas.edu/wp-content/uploads/2014/09/rokers-2eyes3d-JOV2011.pdf)
#         - Sherbakov LO., and Yazdanbakhsh A. (2013). Multiscale sampling model for motion integration, Journal of Vision, 13(11):18, 1–14 [paper](http://cns-classes.bu.edu/~yazdan/pdf/LenaArash13.pdf)
#         - Yazdanbakhsh A. and Gori S. (2011). Mathematical analysis of the Accordion Grating illusion: A differential geometry approach to introduce the 3D aperture problem, Neural Networks, Neural Networks, 24(2011): 1093-1101
#         - Cavanagh, Mather, 1989, Motion: the long and short of it [paper](http://psycnet.apa.org/psycinfo/1990-18848-001)
#         - Weiss, Simoncelli, Adelson, 2002, Motion illusions as optimal percepts [paper](http://www.cc.gatech.edu/~jarek/graphics/papers/10IllusionWeiss.pdf)
#         - Ochs, Brox 2012, Higher order motion models and spectral clustering [paper](https://scholar.google.com/scholar?cluster=12201410412554696015&hl=en&as_sdt=0,10&as_ylo=2011)
#     9. Induced motion and reference frames
#         - Diversity of reference frames for space perception
#         - Induced motion, a case of object-centered reference frame?
#         - Vector subtraction
#         - Induced motion and depth
#         - Perceptive fields
#         - Using aperature problem based motion percept to measure *perceptive fields*
#         - Léveillé J., Yazdanbakhsh A. (2010). Speed, more than depth, determines the strength of induced motion, Journal of Vision, 10(6):10, 1-9. [paper](http://www.cns.bu.edu/~yazdan/Papers/JasYaz10.pdf)
#         - Pack CC, Born RT. (2001). Temporal dynamics of a neural solution to the aperture problem in visual area MT of macaque brain. Nature. Feb 22;409(6823):1040-2.  [paper](http://apps.mni.mcgill.ca/research/cpack/pack_born2001.pdf)
#         - Yazdanbakhsh A. and Gori, S. (2008) A new psychophysical estimation of the receptive field size, Neuroscience Letters, 438(2): 246-251 [paper](http://livingstone.med.harvard.edu/arash/Papers/ArashSimone08.pdf)
#         - Simoncelli, E. P., & Heeger, D. J. (1998). A model of neuronal responses in visual area MT. Vision Res,earch 38(5), 743-61 [paper](http://cns.bu.edu/Profiles/Mingolla.html/cnsftp/pdf/simoncelli-heeger-98.pdf)
#         - Born RT, Bradley DC. (2005) Structure and function of visual area MT.Annu Rev Neurosci. 2005;28:157-89. [paper](http://fisica.uc.pt/data/20052006/apontamentos/apnt_1358_3.pdf)
#         - Grossberg, S. and Rudd, M. E. (1992). Cortical dynamics of visual motion perception: Short-range and long-range apparent motion. Psychological Review, 99(1), 78-121. Read pages 78-82 and 90- 96.
#         - Livingstone MS, Pack CC, Born RT. (2001). Two-dimensional substructure of MT receptive fields. Neuron. Jun; 30(3):781-93.
#         - Albright, T. D., Desimone, R., and Gross, C. G. (1984). Columnar organization of directionally sensitive cells in visual area MT of the macaque. Journal of Neurophysiology, 51, 16-31.
#         - Nishimoto, Gallant, 2011, A three-dimensional spatiotemporal receptive field model explains responses of area MT neurons to naturalistic movies [paper](https://scholar.google.com/scholar?cluster=13672304470069184131&hl=en&as_sdt=0,10&as_ylo=2011)
#     10. Motion based textural segmentation and grouping, color
#         - Object and figure motion in a camouflaged environment
#         - Motion based textural segmentation
#         - Representations for segmentation, again, border-ownership
#         - The effect of cortical magnification on the percept of apparent motion
#         - Opponent and non-opponent chromaticity space
#         - The effect of complementary chromatic induction in grouping
#         - Wurbs J., Mingolla E., and Yazdanbakhsh A. (2013). Modeling a space-variant cortical representation for apparent motion, Journal of Vision, 13(10): 2, 1–17 [paper](http://cns.bu.edu/~yazdan/Papers/WurbsEnnioArash13.pdf)
#         - Yantis, Chapter 17. Mishkin, M. Ungerleider, L. G., and Macko, K. A. (1983). Object vision and spatial vision: Two cortical pathways. Trends in Neurosciences, 6, 414-417. This classic paper launched decades of research and debate.
#         - Livitz G., Yazdanbakhsh A., Eskew RT., and Mingolla E. (2011). Perceiving Opponent Hues in Color Induction Displays, Seeing and Perceiving, 24: 117.
#         - Beck, J. (1993). The British Aerospace Lecture: Visual processing in texture segregation. In D. Brogan, A. Gale and K. Carr, Eds. Visual Search 2. London: Taylor and Francis. Read 1-11, 21-25.
#         - Malik, J. and Perona, P. (1990). Preattentive texture discrimination with early vision mechanisms. Journal of the Optical Society of America A, 7(5), 923-932.
#     11. Binocular vision, binocular rivalry or da Vinci stereopsis?
#         - Disparity and depth
#         - absolute and relative disparity
#         - Hints of absolute and relative disparity in V1 and v2
#         - projection theories
#         - The correspondence problem
#         - Matching algorithms
#         - Occlusion, depth and da Vinci stereopsis
#         - Conditions which lead to binocular rivalry
#         - Kaufman, L. (1974). Binocular stereopsis. In L. Kaufman, Sight and Mind. New York, Oxford University Press, 269-321.
#         - Howard I.P. & Rogers B. J., Seeing in depth: Vol. II. Depth perception. Toronto: Porteous Publisher. A truly comprehensive treatment.
#         - Yazdanbakhsh, A. and T. Watanabe (2004). Asymmetry between horizontal and vertical illusory lines in determining the depth of their embedded surface. Vision Res 44(22): 2621-7.
#         - Blake, R. (1989) A neural theory of binocular rivalry. Psychological Review, 96(1), 145-167. [paper](http://www.psy.gla.ac.uk/~martinl/Assets/MCMPS/Blake_89.pdf)
#         - Nishina, S., A. Yazdanbakhsh, et al. (2007). "Depth propagation across an illusory surface." J Opt Soc Am A Opt Image Sci Vis 24(4): 905-10. [paper](http://cns-web.bu.edu/~yazdan/Papers/ShgYazWatKaw07.pdf)
#         - DeAngelis GC Seeing in three dimensions: the neurophysiology of stereopsis TRENDS COGN SCI 4: (3) 80-90 MAR 2000. [paper](http://www.bcs.rochester.edu/courses/crsinf/504/crsarc/F01/stereo.pdf)
#         - Grossberg S., Yazdanbakhsh A., Cao Y., and Swaminathan G. (2008). How does binocular rivalry emerge from cortical mechanisms of 3-D vision? Vision Research, 48: 2232–2250 [paper](http://cns.bu.edu/~yazdan/Papers/GroYazYgGuru08.pdf)
#         - Nakayama K, & Shimojo S. (1990). da Vinci stereopsis: depth and subjective occluding contours from unpaired image points. Vision Res. 30(11): 1811-25. [paper](http://www.sciencedirect.com/science/article/pii/004269899090161D)
#         - Grossberg S., Srinivasan K., and Yazdanbakhsh A. (2011). On the road to invariant object recognition: How cortical area V2 transforms absolute to relative disparity during 3D vision, Neural Networks, 24(7): 686-92
#         - Marr, D. (1982). Vision. New York, W.H. Freeman. Pages 111-158.
#         - Schwartz, E. (Ed.) (1990). Computational Neuroscience. Cambridge, MA: MIT Press.
#     12. Eye movement, eye tracking, visual attention, pop-out, and search
#         - Types of eye movement: saccade, microsaccade, drift, and tremor
#         - eye movement measures obtained in different labs
#         - attentional modulation of receptive fields
#         - surfaces and features
#         - attention: bottom-up and top-down
#         - feature integration theory
#         - search rate asymmetries: pop-out and slow search
#         - change blindness
#         - Martinez-Conde S., Macknik SL., and Hubel DH. (2004). The role of fixational eye movements in visual perception. Nature Reviews Neuroscience, 5, 229-240 [paper](http://hubel.med.harvard.edu/papers/HubelMartinez-condeetal2004NationReviewNeuroscience.pdf)
#         - Kastner, S. and Ungerleider, L. G. (2000) Mechanisms of visual attention in the human cortex. Annu. Rev. Neurosci.  23:315-341. [paper](http://cns-web.bu.edu/~yazdan/pdf/KastUng.pdf)
#         - Carrasco, 2011, Visual attention: The past 25 years [paper](http://www.cns.nyu.edu/~david/courses/perceptionGrad/Readings/Carrasco-VisRes2011.pdf)
#         - Moran, J. & Desimone, R. (1985). Selective attention gates visual processing in the extrastriate cortex. Science, 229, 782-784. Reprinted as Ch. 26 of K & A. [paper](http://wexler.free.fr/library/files/moran%20(1985)%20selective%20attention%20gates%20visual%20processing%20in%20the%20extrastriate%20cortex.pdf)
#         - Martinez-Conde S., Jorge Otero-Millan, and Macknik SL. (2013).  The impact of microsaccades on vision: towards a unified theory of saccadic function. Nature Reviews Neuroscience, 14(2):83-96 [paper](https://scholar.google.com/scholar?cluster=5055553023324434950&hl=en&as_sdt=0,10)
#         - Itti, L. Koch, C. and Niebur, E. (1998). A model of saliency-based visual attention for Rapid Scene Analysis. IEEE Transactions on Pattern Analysis and Machine Intelligence, vol. 20(11), 1254-1259. [paper](http://th.physik.uni-frankfurt.de/~triesch/courses/260object/papers/IttiEtAl1998.pdf)
#         - Crick, F. (1984). Function of the thalamic reticular complex: The searchlight hypothesis. Proceedings of the National Academy of Science USA, 81, 4586-4590. Reprinted as Ch. 28 of K & A. [paper](http://europepmc.org/articles/PMC345636/pdf=render;jsessionid=deLatUgsmBa2OLcP4wKP.4)
#         - Pollen D.A. (1999) On the neural correlates of visual perception. Cerebral Cortex,9(1):4-19.
#         - Grossberg, S., Mingolla, E. & Ross, W. (1994). A neural theory of attentive visual search: Interactions of visual, spatial, and object representations. Psychological Review, 101(3), 470-489. [paper](http://www.ida.liu.se/~729G15/res/kompendium/METOD_SOS_A_Neural_Theory_of_Attentive_Visual_Search.pdf)
#         - He S, Cavanagh P, Intriligator J. (1996). Attentional resolution and the locus of visual awareness. Nature. Sep 26;383(6598):334-7
#
# **The Visual System** [MIT OpenCourseware](http://ocw.mit.edu/courses/brain-and-cognitive-sciences/9-036-the-visual-system-spring-2005/index.htm) [Online Book thing](http://web.mit.edu/bcs/schillerlab/research.html)
#
# 1. Introduction to the Visual System and Organization of the Retina
#     - Background: Schiller, Peter H. "The Central Visual System." Vision Research 26 (1986): 1351-1355. [Read sections on retina.]
#     - Werblin, F. W., and J. E. Dowling. "Organization of the retina of the mudpuppy, Necturus maculosus. II. Intracellular recording." J Neurophysiol 32 (1969): 339-355. [paper](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.324.9269&rep=rep1&type=pdf)
#     - Waessle, H., and B. B. Boycott. "Functional architecture of the mammalian retina." Physiological Reviews 71 (1991): 447-480.
#     - Dacey, Dennis M. "The mosaic of midget ganglion cells in the human retina." J Neurosci 13 (1993): 5334-5355. [paper](http://www.dei.unipd.it/~enrigri/Public/Biblio/dacey93.pdf)
# 2. The Lateral Geniculate Nucleus: Laminar organization and receptive field properties
#     - Background: Schiller, P. H. "The Central Visual System." Vision Research 26 (1986): 1355-1357. (Read sections on LGN.)
#     - Schiller, P. H., and J. G. Malpeli. "Functional specificity of lateral geniculate nucleus laminae of the rhesus monkey." J Neurophysiol 41 (1978): 788-797.
#     - Hendry, S. H. C., and T. Y. Yoshioka. "A neurochemically distinct third channel in the macaque dorsal lateral geniculate nucleus." Science 264 (1994): 575-577.
# 3. The Striate Cortex: receptive field organization, cytoarchitecture and modularity
#     - Hubel, D., and T. Wiesel. "Receptive fields, binocular interaction and functional architecutre in the cat's visual cortex." J Physiol 160 (1962): 106-154. [paper](http://134.174.13.241/academia/classes/hms_neuro300_vision/readings/gk1852.pdf)
#     - ———. "Past and present ideas about how the visual scene is analyzed by the brain." In Cerebral Cortex. Edited by Rockland, Kaas and Peters. Vol. 12. New York, NY: Plenum Press, 1997. ISBN: 0306455307.
#     - Von der Heydt, R., and E. Peterhans. "Mechanisms of contour perception in monkey visual cortex: 1. Lines of pattern discontinuity." J Neurosci 9 (1989): 1731-1748. [paper](http://www.neurosciences.us/courses/vision2/V1V2/heydt89.pdf)
#     - Schwartz, E. L. "Computational studies of the spatial architecture of primate visual cortex: Columns, maps, and protomaps." In Cerebral Cortex. Edited by A. Peters, and K. S. Rockland. Vol. 10. New York, NY: Plenum Press, 1994. ISBN: 0306455307.
#     - "Chapter 5" in Perception. Edited by R. Sekuler, and R. Blake. New York, NY: McGraw-Hill, 1994. ISBN: 0070579431.
#     - Pasupathy, A., and C. E. Connor. "Population coding of shape in area V4." Nature  Neuroscience 5 (2002): 1332-1338. [paper](http://134.174.13.241/academia/classes/hms_neuro300_vision/readings/gk2092.pdf)
# 13. Visual Illusions
#     - Adelson, E. H. "Lightness Perception and Lightness Illusions." Chapter 24 in The New Cognitive Neurosciences. Edited by M. Gazzaniga. 2nd ed. Cambridge, MA: MIT Press, 2000. p. 339-351. ISBN: 0262071959.
#     - Eysel, U. T. "Neuroscience. Illusions and perceived images in the primate brain." Science 302 (2003): 789-791.
# 14. Visual Prosthesis
#     - Tehovnik, E. J., W. M. Slocum, C. E. Carvey, and P. H. Schiller. "Phosphene induction and the generation of saccadic eye movements by striate cortex." J Neurophysiol 93 (2005): 1-19. [paper](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.326.9609&rep=rep1&type=pdf)
#     - Zrenner, E. "Will retinal implants restore vision?" Science 295 (2002): 1022-1025. [paper](http://www.stat.ucla.edu/~yuille/courses/FIAT_Stat19/handout4b.pdf)

# %% [markdown]
# ** Image Understanding II** [Course site](http://www.cs.ubc.ca/~lowe/525/readings.html)
#
# 1. Introduction
# 2. Stereo vision
#     - Topics: Epipolar geometry and rectification. Correlation and feature matching. Discussion of the first assignment. Belief propagation.
#     - Pascal Fua, "A parallel stereo algorithm that produces dense depth maps and preserves image features," Machine Vision and Applications, 6 (1993), 35--49. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/fua.pdf)
#     - D. Scharstein and R. Szeliski. "A Taxonomy and Evaluation of Dense Two-Frame Stereo Correspondence Algorithms," International Journal of Computer Vision, 47 (2002), pp. 7-42. [Web site with data and source code](http://vision.middlebury.edu/stereo/) [PDF](http://www.cs.ubc.ca/~lowe/525/papers/szeliski-IJCV02.pdf)
#     - Pedro Felzenszwalb and Daniel Huttenlocher, "Efficient Belief Propagation for Early Vision," Conference on Computer Vision and Pattern Recognition (CVPR), 2004. [Presentation](http://cs.brown.edu/~pff/talks/bp.pdf) [Web site with source code](http://cs.brown.edu/~pff/bp/) [PDF](http://www.cs.ubc.ca/~lowe/525/papers/felzen.pdf)
# 3. Image matching and recognition with invariant local features
#     - Interest points. Rotation, scale, and illumination invariance. Image region descriptors. RANSAC. The Hough transform.
#     - Section 4.1, Feature Detection and Matching, from Szeliski's book
#     - David G. Lowe, "Distinctive image features from scale-invariant keypoints," International Journal of Computer Vision, 60, 2 (2004), pp. 91-110. [PDF](http://www.cs.ubc.ca/~lowe/papers/ijcv04.pdf)
#     - M. Calonder, V. Lepetit, C. Strecha, and P. Fua, "BRIEF: Binary Robust Independent Elementary Features," European Conference on Computer Vision (ECCV), 2010. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/calonder_eccv10.pdf)
#     - Articles from Wikipedia: [RANSAC](http://en.wikipedia.org/wiki/RANSAC); [The Hough Transform](http://en.wikipedia.org/wiki/Hough_transform)
# 4. Image registration and 3d reconstruction
#     - Non-linear least-squares with Gauss-Newton. Levenberg-Marquardt. Robust solutions. Solving for 3D structure and camera pose. Dense surface reconstruction.
#     - Section 6.1, Feature-based alignment, from Szeliski's book
#     - Noah Snavely, Steven M. Seitz, Richard Szeliski, "Photo tourism: Exploring photo collections in 3D," ACM Transactions on Graphics (SIGGRAPH), 25(3), 2006, 835-846. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/seitz06.pdf)
#     - Michael Goesele, Noah Snavely, Brian Curless, Hugues Hoppe, Steven M. Seitz, "Multi-View Stereo for Community Photo Collections," ICCV (2007). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/goesele-2007.pdf) [Project web site](http://grail.cs.washington.edu/projects/mvscpc/)
#     - Background reading: [Linear Least Squares](http://en.wikipedia.org/wiki/Linear_least_squares_(mathematics)); [Gauss-Newton Algorithm](http://en.wikipedia.org/wiki/Gauss–Newton_algorithm); [Levenberg-Marquardt](http://en.wikipedia.org/wiki/Levenberg–Marquardt_algorithm);
# 5. Matching and recognition in large datasets
#     - Scaling recognition to large image collections. K-means clustering algorithm. K-d trees. Approximate nearest-neighbour matching in high-dimensional spaces. FLANN.
#     - David Nister and Henrik Stewenius, "Scalable recognition with a vocabulary tree," Conference on Computer Vision and Pattern Recognition, 2006. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/nisterCVPR06.pdf)
#     - Marius Muja and David G. Lowe, "Fast approximate nearest neighbors with automatic algorithm configuration," International Conference on Computer Vision Theory and Applications (VISAPP), 2009. [PDF](http://www.cs.ubc.ca/~lowe/papers/09muja.pdf); [Source code](http://www.cs.ubc.ca/research/flann/)
#     - Articles from Wikipedia: [K-means clustering](http://en.wikipedia.org/wiki/K-means_clustering); [K-d trees](http://en.wikipedia.org/wiki/K-d_tree)
# 6. Learning to recognize object categories
#     - Face detection. The AdaBoost alogorithm. Learning generative and discriminative models. The bag-of-features approach versus learned geometry. Object segmentation from recognition.
#     - Paul Viola and Michael Jones, "Rapid object detection using a boosted cascade of simple features," Conference on Computer Vision and Pattern Recognition, 2001, pp. 511-518. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/violaJones01.pdf)
#     - For background on AdaBoost, read Freund and Schapire, "A short introduction to boosting," JJSAI, 1999. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/freund99short.pdf)
#     - Chapter 14, Recognition, from Szeliski's book
#     - Li Fei-Fei, Rob Fergus, Antonio Torralba, "ICCV 2009 Short Course: Recognizing and Learning Object Categories." [Course page, including Matlab code](http://people.csail.mit.edu/torralba/shortCourseRLOC/index.html)
#     - Bastian Leibe, Edgar Seemann, and Bernt Schiele, "Pedestrian detection in crowded scenes," CVPR 2005, San Diego (June 2005). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/leibe-cvpr05.pdf)
# 7. Scene perception
#     - Recognition of scene categories. Recognition from low-resolution images. Discriminative features for location recognition.
#     - S. Lazebnik, C. Schmid, and J. Ponce, "Beyond Bags of Features: Spatial Pyramid Matching for Recognizing Natural Scene Categories," IEEE Conference on Computer Vision and Pattern Recognition, New York (June 2006). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/lazebnik06.pdf)
#     - A. Torralba, R. Fergus, W. T. Freeman, "80 million tiny images: a large dataset for non-parametric object and scene recognition," PAMI, 30, 11 (2008). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/torralba08.pdf)
#     - Carl Doersch, Saurabh Singh, Abhinav Gupta, Josef Sivic, and Alexei A. Efros, "What Makes Paris Look like Paris?" SIGGRAPH (2012). [PDF](http://graphics.cs.cmu.edu/projects/whatMakesParis/paris_sigg_reduced.pdf) [Project page](http://graphics.cs.cmu.edu/projects/whatMakesParis/)
# 8. Motion tracking and interpretation
#     - Measuring optical flow. Structure from motion. Kalman filter and estimation theory. Color histograms. Tracking with particle filters. Action recognition.
#     - Andrew J. Davison, Ian Reid, Nicholas Molton and Olivier Stasse, "MonoSLAM: Real-Time Single Camera SLAM," IEEE PAMI, (June 2007). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/davison07.pdf) [Davison's web site](http://www.doc.ic.ac.uk/~ajd/)
#     - P. Pérez, C. Hue, J. Vermaak and M. Gangnet, "Color-based probabilistic tracking," European Conference on Computer Vision, ECCV 2002, Copenhagen, Denmark (June 2002). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/perez_eccv02.pdf)
#     - Alexei A. Efros, Alexander C. Berg, Greg Mori and Jitendra Malik, "Recognizing Action at a Distance," International Conference on Computer Vision, Nice, France (2003). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/efros-iccv03.pdf)
# 9. Neurophysiology of vision
#     - Structure of the visual cortex. Higher-level neurophysiology of vision. "What" vs. "where" pathways in the brain. Models of recognition in the brain.
#     - Simon A.J. Winder, "A brief survey of central mechanisms in primate visual perception," (2002). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/winder02.pdf)
#     - R. Quiroga, et al., "Invariant visual representation by single neurons in the human brain," Nature (2005). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/quiroga05.pdf)
#     - T. Serre, L. Wolf, S. Bileschi, M. Riesenhuber and T. Poggio, "Object recognition with cortex-like mechanisms," IEEE PAMI (2007). [PDF](http://www.cs.ubc.ca/~lowe/525/papers/serre07.pdf)
# 10. Deep learning for Vision
#     - The back-propagation algorithm. Convolutional nets. Applications to object category recognition.
#     - Yann Lecun, Marc'Aurelio Ranzato, "Deep Learning Tutorial", ICML (2013). [PDF](http://www.cs.nyu.edu/~yann/talks/lecun-ranzato-icml2013.pdf)
#     - Alex Krizhevsky, Ilya Sutskever, Geoffrey E. Hinton, "ImageNet Classification with Deep Convolutional Neural Networks," NIPS (2012). [PDF](https://www.cs.toronto.edu/~hinton/absps/imagenet.pdf)
#     - M.D. Zeiler, R. Fergus, "Visualizing and Understanding Convolutional Networks," arXiv:1311.2901 (November 2013) [PDF](http://arxiv.org/pdf/1311.2901v3.pdf)
#     - Andrej Karpathy, ConvNetJS: Deep Learning in your browser. Deep learning code that allows for training within your browser using JavaScript. [site](http://cs.stanford.edu/people/karpathy/convnetjs/)
#     - Articles from Wikipedia: [The backpropagation algorithm](http://en.wikipedia.org/wiki/Backpropagation); [Deep learning](http://en.wikipedia.org/wiki/Deep_learning);
# 11. Color vision
#     - Colour spaces. Colour constancy. The use of colour for recognition.
#     - Section 2.3.2, Color, from Szeliski's book
#     - Brian Funt, Kobus Barnard and Lindsay Martin, "Is colour constancy good enough?" European Conference on Computer Vision, (1998), pp. 445-459. [PDF](http://www.cs.ubc.ca/~lowe/525/papers/funt98.pdf)

# %% [markdown]
# - **Computer Vision** [site](vhttp://courses.cs.washington.edu/courses/cse455/12wi/)
#     1. Image Processing (2 weeks)
#         - filtering, convolution
#         - image pyramids
#         - edge detection
#         - features
#         - hough transform
#     2. Image Transformation (2 weeks)
#         - image warping (parametric transformations, resampling, texture mapping)
#         - image compositing (alpha blending, color mosaics)
#         - segmentation and matting (snakes, scissors)
#     3. Motion Estimation (1 week)
#         - optical flow
#         - image alignment
#         - image mosaics
#         - feature tracking
#     4. Light (1 week)
#         - physics of light
#         - color
#         - reflection
#         - shading
#         - shape from shading
#         - photometric stereo
#     5. 3D Modeling (3 weeks)
#         - projective geometry
#         - camera modeling
#         - single view metrology
#         - camera calibration
#         - stereo
#     6. Object Recognition and Applications (1 week)
#         - eigenfaces
#         - applications (graphics, robotics)
#
#     7. Readings:
#         - Linear Filters
#             - Forsyth, D.A. and Ponce, J.  Computer Vision: A Modern Approach.  Prentice Hall, 2002, pp. 203-215.
#          - Optical Flow
#             - Trucco, E. and Verri, A.  Introductory Techniques for 3-D Computer Vision.  Prentice Hall, 1998, pp. 191-199.
#          - Image Formation
#             - Nalwa, Vishvjit S.  A Guided Tour of Computer Vision.  Addison Wesley, 1993, Chap. 2.1, pp. 30-48.
#          - Stereo
#             - Trucco, E. and Verri A.  Introductory Techniques for 3-D Computer Vision.  Prentice Hall, 1998, pp. 139-163.
#          - Shading
#             - Watt, A.  The Computer Image.  Addison-Wesley, 1998.  pp. 64-71 and 102-115.
#          - Photometric Stereo
#             - Forsyth, D.A. and Ponce, J.  Computer Vision: A Modern Approach.  Prentice Hall, 2003, pp. 80-86.
#          - Statistical Pattern Recognition
#             - Bishop, Christopher M.  Neural Networks for Pattern Recognition.  Oxford University Press, 1995, Chap. 1
#          - Hough Transform
#             - Watt, A.  The Computer Image.  Addison-Wesley, 1993, pp. 255-289.
#          - Image Segmentation
#             - Shapiro and Stockton. Computer Vision. Prentice Hall, 2001, pp. 279-289.
#          - The Human Visual System
#             - Glassner, Andrew S.  Principles of Digital Image Synthesis.  Morgan Kaufmann Publications, 1995, pp. 5-32.

# %% [markdown]
# - **Computer Vision** [Course Page](http://cs.nyu.edu/%7Efergus/teaching/vision/index.html)
#     1. Introduction, Image Formation I
#     2. Image Formation II
#     3. Filtering and Edges
#     4. Lighting, Color
#     5. Corner and Region Detection
#     6. Region representation
#     7. Fitting, RANSAC
#     8. Image Alignment, Optical Flow
#     9. Epipolar geometry
#     10. Stereo reconstruction
#     11. Mutiview Stereo, Structure from Motion
#     12. Structure from Motion
#     13. Introduction to Recognition
#     14. Specific Object Recognition
#     15. Faces
#     16. Recognition - Bag of words I
#     17. Recognition - Bag of words II
#     18. Recognition - Parts-based models I
#     19. Recognition - Parts-based models II
#     20. Neural Networks I
#     21. Parts and Structure Models III
#     22. Segmentation
#     23. Recognition - Boosting
#     24. Recognition - Neural Networks II
#     25. Recognition - Neural Networks III
#     26. Recognition - Neural Networks IV
#     27. Deep Learning I
#     28. Deep Learning II
#     - Texts:
#         - Szeliski, Richard, Computer Vision: Algorithms and Applications Springer, 2011.
#         - Forsyth, David A., and Ponce, J. Computer Vision: A Modern Approach, Prentice Hall, 2003.
#         - Hartley, R. and Zisserman, A. Multiple View Geometry in Computer Vision, Academic Press, 2002.
#         - Palmer, Stephen E. Vision Science: Photos to Phenomenology, MIT Press, 1999.
#         - Strang, Gilbert. Linear Algebra and Its Applications 2/e, Academic Press, 1980.
#         - Wandell, Brian A. Foundations of Vision, Sinauer, 1995.
#
# - **Computer Vision** [Page](https://courses.engr.illinois.edu/cs543/sp2015/)
#
#     1. Interpreting Intensity
#         - Light, Shading, and Color
#         - Linear Filters, Spatial Domain
#         - Linear Filters, Frequency Domain
#         - Templates and Image Pyramids
#             - Adelson 1983 - The Laplacian Pyramid [link](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.40.1728&rep=rep1&type=pdf)
#         - Edge Detection
#             - Berkely Pb Detector [link](http://www.eecs.berkeley.edu/Research/Projects/CS/vision/grouping/papers/mfm-pami-boundary.pdf)
#             - Detection with Mutual Information [link](http://web.mit.edu/phillipi/www/publications/crisp_boundaries.pdf)
#     2. Correspondence and Alignment
#         - Interest Points
#             - Local Features [link](http://www.cs.utexas.edu/~grauman/courses/fall2009/papers/local_features_synthesis_draft.pdf)
#             - Distinctive Image Features from Scale-Invariant Keypoints [link](http://www.cs.ubc.ca/~lowe/papers/ijcv04.pdf)
#         - Feature tracking, optical flow
#             - Features and Stereo [link](http://www.ces.clemson.edu/~stb/klt/lucas_bruce_d_1981_1.pdf)
#             - Kanade-Lucas-Tomasi Feature Tracker [link](http://www.ces.clemson.edu/~stb/klt/)
#         - Fitting and Alignment
#         - Alignment and object instance recognition
#             - Object Recognition from Local Scale-Invariant Features [link](http://people.cs.ubc.ca/~lowe/papers/iccv99.pdf)
#     3. Perspective and 3D Geometry
#         - Camera models
#         - Single-view geometry and calibration
#             - Single view geometry [link](https://courses.engr.illinois.edu/cs543/sp2011/materials/3dscene_book_svg.pdf)
#         - Image switching
#             - Panoramic switching [link](http://cs.bath.ac.uk/brown/papers/ijcv2007.pdf)
#         - Epipolar geometry, stereo
#             - Epipoloar geometry and the Fundamental Matrix [link](http://www.robots.ox.ac.uk/~vgg/hzbook/hzbook1/HZepipolar.pdf)
#         - Structure from motion
#             - Shape and Motion from Image Streams under Orthography [link](http://citeseer.ist.psu.edu/viewdoc/download;jsessionid=0254F9002D5BB94140D10B290526A7AB?doi=10.1.1.131.9807&rep=rep1&type=pdf)
#     4. Grouping and Segmentation
#         - Clustering, K-means
#             - Cluster Analysis [WIKI](http://en.wikipedia.org/wiki/Cluster_analysis)
#         - Gestalt Cues and Image Segmentation
#             - Intro to Mean Shift Algorithm [link](https://saravananthirumuruganathan.wordpress.com/2010/04/01/introduction-to-mean-shift-algorithm/)
#             - Boundaries and Watershed [link](http://www.eecs.berkeley.edu/~arbelaez/publications/Arbelaez_Maire_Fowlkes_Malik_CVPR2009.pdf)
#         - EM Algorithm, Mixture of Gaussians
#             - Expectation-Maximaization Tutorial [link](http://www-ssli.ee.washington.edu/people/bulyko/papers/em.pdf)
#         - MRFs and Graph Cut Segmentation
#             - What Energy Functions Can be Maximized via Graph Cuts? [link](http://www.cs.cornell.edu/~rdz/Papers/KZ-PAMI04.pdf)
#     5. Categorization and Object Recognition
#         - Face recognition
#             - Face recognition: a literature survey [link](http://www.umiacs.umd.edu/~wyzhao/ACM_FaceSurvey.htm)
#         - Image features and categorization
#             - Categorizing images and regios [link](https://courses.engr.illinois.edu/cs543/sp2011/materials/3drepresentationsbook_chapter5_categorization.pdf)
#             - Indexing and Visual Vocabularies [link](http://www.cs.utexas.edu/~grauman/courses/fall2009/papers/bag_of_visual_words.pdf)
#         - Classification
#         - Object detection with statistical templates
#         - Object detection with parts-based models
#             - Parts-based Category Models [link](http://www.cs.utexas.edu/~grauman/courses/fall2009/papers/partbased.pdf)
#         - Object tracking with Kalman filters
#     6. Advanced Topics
#         - Action Recognition
#         - Convolutional Neural Networks
#         - 3D Scenes and Context
#             - Hoiem and Savarese, Ch. 1, 4, 16 [link](https://courses.engr.illinois.edu/cs543/sp2015/materials/HoiemSavarese_3dSceneAndObject_draft.pdf)
#             - Hoiem et al 2007 [link](http://web.engr.illinois.edu/~dhoiem/publications/hoiem_ijcv2007SurfaceLayout.pdf)
#             - Hedau et al 2009 [link](http://web.engr.illinois.edu/~dhoiem/publications/iccv2009_hedau_indoor.pdf)
#
# - **Computer Vision: Foundations and Applications** [Course Page](http://vision.stanford.edu/teaching/cs131_fall1415/schedule.html)
#     - Introduction
#         1. Introduction to Computer Vision
#         2. Linear Algebra Primer
#         3. Optional MATLAB Tutorial
#     - Pixels, Features, and Cameras
#         4. Pixels and Filters
#         5. Edge detection, RANSAC, Feature detectors, Harris
#         6. Difference of Gaussians, SIFT
#         7. Camera 1
#         8. Camera 2
#         9. Camera 3
#         10. Panorama Stitching
#         11. Human Vision: Insights and Inspiration for Computer Vision
#         12. Basic Concepts of Segmentation
#         13. K-means Clustering
#         14. Figure-ground Segmentation using Clustering Algorithms
#         15. Segmentation in Human Vision: Implicatiosn for Computer Vision
#     - Regions of Images, and Segmentation
#         16. Basic Concepts of Segmentation
#         17. K-means clustering
#         18. Feature tracking
#         19. Figure-ground segmentation using Clustering Algorithms
#         20. Segmentation in Human Vision: Implications for Computer Vision
#     - Recognizing Objects and Faces
#         16. Basic Concepts in Recognition, Nearest Neighbor Match
#         17. PCA and Eigenfaces
#         18. Tracking Millions of People
#         19. Networks and Hierarchical Processing: Object Recognition in Human and Computer Vision
#
# - **High-Level Vision: Behaviors, Neurons, and Computational Models** [Course mats](http://vision.stanford.edu/teaching/cs431_spring1314/syllabus.html) [more from 2011]
#     1. Introduction: Vision - are models of object recognition catching up with the brain?
#     2. Functional organization of high-level visual cortex and its relation to perception
#     3. The importance of cortical connections
#     4. Information processing in the primate visual system
#     5. Neocognitron: A hierarchical neural network
#     6. A feedforward architecture accounts for rapid categorization
#     7. Image interpretation by a single bottom-up top-down cycle categorization
#     8. How Does the Brain Solve Visual Object Recognition?
#     9. Invariance and selectivity in the ventral visual pathway
#     10. Hierarchical Bayesian inference in the visual cortex
#     11. Learning AND-OR Templates for Object Recognition and Detection
#     12. Basic objects in natural categories
#     13. Matching Categorical Object Representations in Inferior Temporal Cortex of Man and Monkey
#     14. Hedging Your Bets: Optimizing Accuracy- Specificity Trade-offs in Large Scale Visual Recognition
#     15. Unsupervised Learning of Invariant Feature hierarchies with Applications to Object Recognition
#     16. ImageNet Classification with Deep Convolutional Neural Networks
#     17. View from the Top: Hierarchies and Reverse Hierarchies in the Visual System

# %% [markdown]
# - **Advanced Reading in Computer Vision** [Page](http://vision.stanford.edu/teaching/cs331_winter14/syllabus.html)
#     1. Introduction
#     2. Knowledge Base: Cyc and Freebase
#     3. Making systems that use statistical reasoning easier to build and maintain over time
#     4. Using Freebase for learning Relations
#     5. Semantic Parsing on Freebase from Question-Answer Pairs
#     6. NELL (Never Ending Language Learning)
#     7. NEIL (Never Ending Image Learning)
#     8. Connecting Linguistic and Geometric Knowledge by Observing the World
#     9. Games for generating descriptions
#     10. Jointly learning to Parse and perceive
#     11. Watson Deep QA
#     12. Image to Text
#     13. Reasoning with Neural Tensor Networks
#     14. Physics Based Knowledge (blocks world)
#     15. Robots Learning Language
#     16. Vision + Language
#
# - **The Cutting Edge of Computer Vision** [page](http://vision.stanford.edu/teaching/cs231b_spring1213/project.html)
#
#     1. Project 1: Pedestrian Detection with the Deformable Part Model
#         - P.Viola and M.Jones. Rapid Object Detection using a Boosted Cascade of Simple Features. CVPR 2001.
#         - N.Dalal and B.Triggs. Histograms of Oriented Gradients for Human Detection. CVPR 2005.
#         - P.Felzenszwalb, D.McAllester, and D.Ramanan. A Discriminatively Trained, Multiscale, Deformable Part Model. CVPR 2008.
#         - P.Felzenszwalb, R.Girshick, D. McAllester, and D.Ramanan. Object Detection with Discriminatively Trained Part-Based Models. PAMI 2010.
#         - P.Felzenszwalb, R.Girshick, and D.McAllester. Cascade Object Detection with Deformable Part Models. CVPR 2010.
#     2. Project 2: Interactive Image Segmentation with GrabCut
#         - Y.Boykov and M.Jolly. Interactive Graph Cuts for Optimal Boundary and Region Segmentation of Objects in N-D Images. ICCV 2001.
#         - C.Rother, V.Kolmogorov, and A.Blake. "GrabCut" - Interactive Foreground Extraction using Iterated Graph Cuts. SIGGRAPH 2004.
#         - R.Szeliski, R.Zabih, D.Scharstein, O.Veksler, V.Kolmogorov, A.Agarwala, M.Tappen, and C.Rother. A Comparative Study of Energy Minimization Methods for Markov Random Fields with Smoothness-Based Priors. PAMI 2008.
#         - V.Lempitsky, P.Kohli, C.Rother, T.Sharp. Image segmentation with a Bounding Box Prior. ICCV 2009.
#     3. Project 3: Locality-constrained Linear coding for Scene and Action Classification
#         - S.Lazebnik, C.Schmid, and J.Ponce. Beyond Bags of Features: Spatial Pyramid Matching for Recognizing Natural Scene Categories. CVPR 2006.
#         - J.Wang, J.Yang, K.Yu, F.Lv, T.Huang, and Y.Gong. Locality-constrained Linear Coding for Image Classification. CVPR 2010.
#         - V. Delaitre, I. Laptev, and J. Sivic. Recognizing Human Actions in Still Images: A Study of Bag-of-Features and Part-Based Representation. BMVC 2010.
#         - J.Li, H.Su, E.Xing, and L.Fei-Fei. Object Bank: A High-Level Image Representation for Scene Classification & Semantic Feature Sparsification. NIPS 2010.
#         - B.Yao and L.Fei-Fei. Grouplet: A Structured Image Representation for Recognizing Human and Object Interactions. CVPR 2010.
#
# - **Advances in Computer Vision** [page](http://6.869.csail.mit.edu/fall14/schedule.html)
#     1. Intro and simple vision system
#     2. Matlab tutorial
#     3. Matlabl tutorial
#     4. Linear filters
#     5. Filters, Quadrature, Pyramids
#     6. Filtering tutorial
#     7. Learned feedforward visual processing
#     8. Color and constancy
#     9. Image statistics I
#     10. Image statistics II
#     11. Graphical models and belief propagation
#     12. Texture
#     13. Edges and segmentation
#     14. Image formation, camera, lenses and calibration
#     15. Homogeneous coordinates. stereo. Multi-view geometry
#     16. Shape from X
#     17. Image features
#     18. Homographies, RANSAC, and panoramas
#     19. Motion: continuous
#     20. Motion: discrete
#     21. Object recognition I
#     22. Object recognition II
#     23. Object recognition III
#     24. Scene recognition
#     25. Object recognition in context
#     26. Recognition
#     27. Tracking
#     28. **How to write a paper and give a talk**
#
# - **Learning-Based Methods in Vision** [page](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/)
#     1. *Introduction*
#         - Introduction, Vision: Measurement v. Perception
#         - Overview lecture on theories of visual perception
#             - Cavanagh, 1995, Vision is getting easier every day [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/cavanagh-perception-95.pdf)
#             - Cavanagh, 1991, What's up in top-down processing? [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/cavanagh-whatsup-91.pdf)
#             - Cavanagh, 2005, The Artist as Neuroscientist [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/CavanaghNature.pdf)
#             - Nakayam, 1998, Vision fin-de-siecle - a reductionistic explanation of perception for the 21st century? [paper](http://bork.hampshire.edu/~bart/temp/art3.pdf)
#             - Overview lecture on the physiology of vision
#             - Adelson & Bergen, 1991, The Plenotopic Function and the Elements of Early vision [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/adelson-elements-91.pdf)
#     2. **Images**
#         - *Learning Features from Data*
#             - Olshausen, Field 1996, Wavelet-like receptive fields emerge from a network that learns sparse codes for natural images [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/olshausen-nature-96.pdf)
#             - Olshausen & Field, 2000, Vision and the Coding of Natural Images [paper](http://redwood.psych.cornell.edu/papers/olshausen_field_2000_amsci.pdf)
#             - Serre, Wolf, Poggio, 2005, Object Recognition with Features Inspired by Visual Cortex [paper](http://cbcl.mit.edu/software-datasets/standardmodel/cvpr05.pdf)
#         - *Distributions of Features*
#             - Rubner, Tomasi, Guibas, 2000 [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/rubner-jcviu-00.pdf)
#             - Levina, Bickel, 2001, [paper](http://dept.stat.lsa.umich.edu/%7Eelevina/EMD.pdf)
#             - Martin, Fowlkes and Malik (2004) [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/martin-pami-04.pdf)
#         - *Images as Texture ("Bag of Words" models)*
#             - Renninger, Malik, 2004 When is scene identification just texture recognition? [paper](http://www.cs.cmu.edu/~efros/courses/LBMV07/Papers/walker-vr-04.pdf)
#             - Csurka, et al 2004, Visual Categorization with Bags of Keypoints [paper](http://www.cs.cmu.edu/~efros/courses/LBMV07/Papers/csurka-eccv-04.pdf)
#             - Winn, Criminisi and Minka 2005, Object Categorization by Learned Universal Visual Dictionary
#         - *Images as Scenes*
#             - Torralba, Oliva 2003, Statistics of natural image categories [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/torralba-network-03.pdf)
#             - Torralba, Oliva 2002, Depth Estimation from Image structuree [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/torralba-pami-02.pdf)
#             - Oliva, Torralba, 2001, Modeling the Shape of the Scene: A Holistic Representation of the Spatial Envelope [paper](http://www.cs.cmu.edu/%7Eefros/courses/LBMV07/Papers/oliva-ijcv-01.pdf)
#         - *Images as Feature Vectors*
#             - Roweis, Saul 2000, Nonlinear Dimensionality Reduction by Locally Linear Embedding [paper](http://www.cs.cmu.edu/~efros/courses/LBMV07/Papers/roweis-science-00.pdf)
#             - Tenenbaum, Silva, Langfod, 2000, A Global Geometric Framework for Nonlinear Dimensionality Reduction [paper](http://www.cs.cmu.edu/~efros/courses/LBMV07/Papers/tenenbaum-science-00.pdf)
#             - Pless 2003, Using isomap to explore video sequences [paper](http://www.cse.wustl.edu/%7Epless/papers/imageSpaces.pdf)
#             - Pless & Simon 2002, Using Thousands of Images of an Object [paper](http://www.cs.wustl.edu/%7Epless/papers/plessSimonThousandsCVPRIP.pdf)
#             - Winnemoller, et al 2005, Light Waving: Estimating Light Positions from Photographs Alone [paper](http://www.cs.northwestern.edu/%7Ejet/docs/2005LightWavingFinal.pdf)
#              - Tenenbaum & Freeman, 2000, Separating Style and Content with Bilinear Models [paper](http://www.cs.cmu.edu/~efros/courses/LBMV07/Papers/tennebaum-neuralcomp-00.pdf)
#         - *Image matching (Distance transforms)*
#             - Learned-Miller 2005, Data Driven Image Models through Continuous Joint Alignment
#             - Huttenlocker et al 1993, Comparing Images Using the Hausdorff Distance
#             - Borgefors 1988, Hierarchical Chamfer Matching: A Parametric Edge Matching Algorithm
#             - Huttenlocker & Felzenswalb 2004, Distance Transforms of Smapled Functions
#         - *Image Correspondence*
#             - Zhang, et al 2006, SVM-KNN: Discriminative Nearest Neighbor Classification for Visual Category recognition
#             - Frome, Singer, Malik, 2006, Image Retrieval and Recognition Using Local Distance Functions
#             - Berg, Berg, and Malik, 2005, Shape Matching and Object Recognition using Low Distortion Correspondences
#             - Leordeanu, Herbert 2005, A Spectral Technique for Correspondence Problems using Pairwise Constraints
#         - *Lots of Data is Fun!*
#             - Lazebnik, Schmid, Ponce, 2006, Beyond Bags of Features: Spatial Pyramid Matching for Recognizing Natural Scene Categories
#             - Gauman & Darrell, 2005, The Pyramid Match Kernel: Discriminative Classification with Sets of image Features
#             - Sivic and Zisserman, 2003, Video Google: A Text Retrieval Approach to Object Matching in Videos
#             - Nister & Stewenues, 2006, Scalable Recognition with a Vocabulary Tree
#             - Zitnik & Kanade, 2003, Content-free image retrieval
#             - Berg et al, Names and Faces
#             - Dalal and Triggs 2005, Histograms of Oriented Gradients for Human Detection
#             - Marszalek and Schmid, 2006, Spatial weighting for bag-of-features
#             - Snavely, Seitz, and Szeliski, 2006, Photo tourism: Exploring photo collections in 3D
#         - *Boosting Background*
#             - AdaBoost background
#             - Friedman, Hastie, & Tibshirani, 1998, Additive Logitic Regression: a Statistical View of Boosting
#             - Schneiderman, Kanade, 2004, Object Detection Using the Statitics of parts
#             - Viola & jones, 2001, Robust Real-time Object Detection
#     3. **Objects and Parts**
#         - *Segmentation*
#             - Wertheimer, 1923, Laws of Organization in Perceptual Forms
#             - Weiss, 1999, Segmentation using eigenvectors: a unifying view
#             - Ng, Jordan, & Weiss, 2001, On Spectral Clustering: Analysis and an algorithm
#             - Tu and Zhu, 2002, Image Segmentation by Data-Driven Markov Chain Monte Carlo
#             - Boykov and Jolly 2001, Interactive Graph Cuts for Optimal boundary and Region Segmentation of Objects in ND Images
#             - Li, et al, 2004, Lazy Snapping
#         - *Grouping Repeated Structures*
#             - Boiman & Irani, 2006, Similarity by Composition
#             - Kannan, Winn, & Rother, 2006, Clustering appearance and shape by learning jigsaws
#             - Ren & Malik 2003, Learning a Classification Model for Segmentation
#             - Russel, et al 2006, Using Multiple Segmentations to Discover Objects and their Extent in Image Collections
#         - *From Features to Objects*
#             - Torralba, et al, Sharing visual features for multiclass and multiview object recognition
#             - Opelt et al 2006, Incremental learning of object detectors using a visual shape alphabet
#             - Ferrari, et al 2006, Groups of Adjacent Contour Segments for Object Detection
#             - Leibe, et al 2004, Combined Object Categorization and Segmentation with an Implicit Shape Model
#             - Leibe, et al 2005, Pedestrian Detection in Crowded Scenes
#         - *Scene, Context, and Image Parsing*
#             - Saxena, et al 2005, Learning Depth from Single Monocular Images
#             - Hoiem, et al 2005, Geometric Context from a Single Image
#             - Tu et al 2005, Image Parsing: Unifying Segmentation, Detection, and Recognition
#             - Ren, et al 2006, Figure/Ground Assignment in Natural Images
#             - Cornelis, et al 2006, 3D City Modeling Using Cognitive Loops
#         - *Face Modeling/Recognition*
#             - Sinha, et al, Face recognition by humans: 20 results all computer vision researchers should know about
#             - Cootes, et al 1998, Active Appearance models

# %% [markdown]
# - Vision and learning - computers and brains [Page](http://web.mit.edu/course/other/i2course/www/vision_and_learning_fall_2013.html)
#     1. M-theory: Learning representations for learning like humans learn
#     2. Sensory gating, integration and prediction
#     3. Learning in Spiking Networks
#         - Gutig R, Sompolinsky H (2005). The tempotron: a neuron that learns spike timing-based decisions. Nature Neuroscience 9, 42-428.
#         - Gutig R, Sompolinsky H (2009). Time-Warp-Invariant Neuronal Processing. PLoS Biol 7(7).
#     4. Computational Reinforcement Learning
#         - Recent developments in RL: Kober J, Bagnell JA, and Peters J (2013) Reinforcement Learning in Robotics: A Survey. Int. Journal of Robotics Research.
#     5. Cortical processes for navigating complex acoustic environments
#     6. Computer Perception with Deep Learning
#     7. Reinforcement learning in the brain
#     8. Machine Learning Approaches to Face Detection and Related Problems
#         -  P. Viola and M. Jones (2001). Rapid object detection using a boosted cascade of simple features CVPR.
#         - R. Schapire and Y. Singer (1999). Improved boosting algorithms using confidence-rated predictions . Machine Learning.
#     9. The neural computations that underlie face processing in primates
#         - Kanwisher N, McDermott J, & Chun M (1997). The Fusiform Face Area: A Module in Human Extrastriate Cortex Specialized for the Perception of Faces. Journal of Neuroscience. 17 4302-4311.
#         - Freiwald WA, Tsao DY,( 2010). Functional compartmentalization and viewpoint generalization within the macaque face-processing system. Science Vol. 330 no. 6005 pp. 845-851.
#         - Issa EB, DiCarlo JJ (2012). Precedence of the eye region in neural processing of faces. J. Neurosci. 32(47):16666-82.
#         - Tan, C. and T. Poggio (2013). Faces as a Model Category" for Visual Object Recognition. MIT-CSAIL-TR-2013-004, CBCL-311, Massachusetts Institute of Technology, Cambridge, MA, March 18.
#     10. Using machine learning to understand biological vision and learning
#         - S Chase, A Schwartz (2011) Inference from populations: going beyond modelsProgress in Brain Research, Vol. 192
#         - F Tong, MS Prattle (2012) Decoding patterns of human brain activity. Annu Rev Psychol 64:483-509.
#         - E Meyers, XL Qi, C Constantinidis (2012). Incorporation of new information into prefrontal cortical activity after learning working memory tasks. PNAS, 108:4651-4656.

# %% [markdown]
# - **Perception and attention** [Page](http://www.cns.nyu.edu/~david/courses/perceptionGrad/syllabus2013.html)
#     1. Color: trichomacy, color opponency and chromatic adaptation
#     2. Detection and signal detection theory
#     3. Linear systems theory: spatial vision
#     4. Linear systems theoy: auditory channels
#     5. Attention
#     6. Visual Motion Perception
#     7. Cue combination and Bayesian decision theory
#     8. Recognition

# %% [markdown]
# - **Machine Vision** [page](http://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-801-machine-vision-fall-2004/index.htm)
#     1. Estimating Image Motion Field; Pinhole Camera Model
#     2. Lambertian Surfaces; Image Motion in 2D
#     3. Constant Brightness Equation
#     4. Binocular Stereo
#     5. Reflectance Map: Image Formation, Surface Relectance, Surface Orientation
#     6. Brightness Distribution Function
#     7. Shape from Shading
#     8. Shape from Gradient
#     9. Binary Image Processing
#     10. The Euler Equations and their Applications
#     11. Optical Flow
#     12. Motion Vision and Motion Field
#     13. Direction Motion Vision
#     14. Extended Gaussian Images; Geometry
#     15. Tessellation, Platonic solids
#     16. Quaternions, Operations on EGIs
#     17. Photogrammetry; Absolute, Exterior, and Interior Orientation
#     18. Relative Orientation
#     19. Parallel Networks; How to Process Images Efficiently

# %% [markdown]
# - **Deep Learning Methods for Vision** [page](http://cs.nyu.edu/~fergus/tutorials/deep_learning_cvpr12/)
#     1. Introduction
#     2. Sparse Coding
#     3. Neural Networks
#     4. Restricted Boltzmann Machines
#     5. Transfer Learning
#     6. Motion and Video
#
# - **Advanced Topics in Computer Vision** [page](http://www.wisdom.weizmann.ac.il/~vision/courses/2010_2/topics_papers.html)
#     1. Denoising
#         - Image denoising using scale mixtures of gaussians in the wavelet domain , J. Portilla, V. Strela, M. Wainwright, E. Simoncelli.  In IEEE Trans. Image Processing, 2003.
#         - A review of image de-noising methods, with a new one. , A. Buades, B. Coll, J. Morel.  In SIAM Journal on Multiscale Modeling and Simulation, 2005.
#         - Image denoising by sparse 3-D transform-domain collaborative ﬁltering. , K. Dabov, A. Foi, V. Katkovnik, K. Egiazarian.  In IEEE Trans. Image Processing, 2007.
#         - A Tour of Modern Image Processing. , P. Milanfar.  Invited feature article in review IEEE Signal Processing Magazine, 2010.
#         - Image Quality Assessment: From Error Visibility to Structural Similarity. , W. Zhou, A.C. Bovik, H.R. Sheikh, E.P Simoncelli.  In IEEE Trans. Image Processing, 2004.
#     2. Compressed Sensing
#         - An Introduction To Compressive Sampling , E.J. Candes, M.B. Wakin.  In IEEE Signal Processing Magazine, March 2008.
#         - Learning compressed sensing , Y. Weiss, H.S. Chang, W.T. Freeman.  In Snowbird Learning Workshop, 2007.
#         - Stable signal recovery from incomplete and inaccurate measurements , E. Candesy, J. Romberg, T. Tao.  In Comm. Pure Appl. Math., August 2006.
#         - Sparse MRI: The Application of Compressed Sensing for Rapid MR Imaging , M. Lustig, D. Donoho, J.M. Pauly.  In Magnetic Resonance in Medicine, 2007.
#         - Single-pixel imaging via compressive sampling , M. Duarte, M. Davenport, D. Takhar, J. Laska, T. Sun, K. Kelly, R. Baraniuk.  In IEEE Signal Processing Magazine, March 2008.
#     3. Super-Resolution (in images)
#         - Improving resolution by image registration , M. Irani, S. Peleg.  In CVGIP: Graphical Models and Image Processing, 1991.
#         - Limits on super-resolution and how to break them , S. Baker, T. Kanade.  In PAMI, 2002.
#         - Fundamental Limits of Reconstruction-Based Superresolution Algorithms under Local Translation , Z. Lin, H. Shum.  In PAMI, 2004.
#         - Example based super-resolution , W.T. Freeman, T.R. Jones, E.C. Pasztor.  In Comp. Graph. Appl., 2002.
#         - Super-resolution from a single image , D. Glasner, S. Bagon, M. Irani.  In ICCV 2009.
#     4. Shape from Illumination
#         - Shape from Shading: A Survey , R. Zhang, P. Tsai, J.E. Cryer, M. Shah.  In PAMI 1999.
#         - Optimal Algorithm for Shape from Shading and Path Planning , R. Kimmel, J.A. Sethian.  In Journal of Mathematical Imaging and Vision, 2001.
#         - Efficient Belief Propagation for Vision Using Linear Constraint Nodes , B. Potetz.  In CVPR 2007.
#         - Shape from shading using graph cuts , J.Y. Chang, K.M. Lee, S.U. Lee.  In Journal of Pattern Recognition, 2008.
#     5. Deep Learning
#         - Learning multiple layers of representation , G.E. Hinton.  In TRENDS in Cognitive Sciences, 2007.
#         - Reducing the dimensionality of data with neural networks , G.E. Hinton, R.R. Salakhutdinov.  In Science, July 2006.
#         - Convolutional deep belief networks for scalable unsupervised learning of hierarchical representations , H. Lee, R. Grosse, R. Ranganath, A.Y. Ng.  In ICML, 2009.
#         - What is the Best Multi-Stage Architecture for Object Recognition? , K. Jarrett, K. Kavukcuoglu, M. Ranzato, Y. LeCun.  In ICCV, 2009.
#         - Exploring Strategies for Training Deep Neural Networks , H. Larochelle, Y. Bengio, J. Louradour, P. Lamblin.  In Journal of Machine Learning Research, 2009.
#     6. Random forests
#         - Semantic Texton Forests for Image Categorization and Segmentation , J. Shotton, M. Johnson, R. Cipolla.  In CVPR 2008.
#         - Object Class Segmentation using Random Forests , F. Schroff, A. Criminisi, A. Zisserman.  In BMVC 2008.
#         - Randomized Trees for Real-Time Keypoint Recognition , V. Lepetit, P. Lagger, P. Fua.  In CVPR 2005.
#         - Regression forests for efficient anatomy detection and localization in CT studies , A. Criminisi, J. Shotton, D. Robertson, E. Konukoglu.  In MICCAI MCV 2010.
#         - Fast discriminative visual codebooks using randomized clustering forests , F. Moosmann, B. Triggs, F. Jurie.  In NIPS 2006.
#         - MIForests: multiple-instance learning with randomized trees , C. Leistner, A. Saffari, H. Bischof.  In ECCV 2010.
#     7. Pascal Grand Challenge
#         - Image Classification Using Super-Vector Coding of Local Image Descriptors , X. Zhou, K. Yu, T. Zhang, T.S. Huang.  In ECCV 2010.
#         - Object Detection with Discriminatively Trained Part-Based Models , P.F. Felzenszwalb, R.B. Girshick, D. McAllester, D. Ramanan.  In PAMI 2010.
#         - Unbiased Look at Dataset Bias , A. Torralba, A. Efros.  In CVPR 2011.
#         - Multiple Kernels for Object Detection , A. Vedaldi, V. Gulshan, M. Varma, A. Zisserman.  In ICCV 2009.
#         - The PASCAL Visual Object Classes (VOC) Challenge , M. Everingham, L. Van Gool, C.K.I. Williams, J. Winn, A. Zisserman.  In IJCV 2010.
#
# - **Introduction to Computer Vision** [page](http://www.wisdom.weizmann.ac.il/~vision/courses/2015_1/intro_to_vision/schedule.html)
#     1. Fourier I
#     2. Fourier II
#     3. Geometry I
#     4. Geometry II
#     5. Geometry III
#     6. Geometry IV
#     7. Israel Computer Vision Day 2014
#     8. Motion I - optical flow
#     9. Human Vision
#     10. Motion II - image alignment
#     11. Lighting
#     12. Recognition
